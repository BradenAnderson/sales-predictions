# %% [markdown]
# <a href="https://colab.research.google.com/github/BradenAnderson/sales-predictions/blob/main/04_Feature_Engineering_and_Modeling_Pt2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Braden Anderson
# ## Sales Predictions Project
# ## Feature Engineering and Modeling Part 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import missingno
import pickle
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats

from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge, LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, BaggingRegressor 
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler, PowerTransformer
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import r2_score, mean_squared_error, SCORERS
from sklearn.pipeline import Pipeline


# %matplotlib inline

# %%
# Importing the original data (NOT what was previously cleaned).
filename = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/sales_predictions.csv'

sales_df = pd.read_csv(filename)

# %%
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Consider any products with item_visibility = 0 as having missing information. (Not realistic that the visibility of any item in a store is actually zero).
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Calculate the average visibility for each unique value of 'Item_Identifier'
average_visibility = sales_df.groupby(by='Item_Identifier')['Item_Visibility'].mean()

# Create a filter to find all the rows where the visibility value is zero.
missing_visibility_filter = (sales_df['Item_Visibility'] == 0)

# Change all values of visibility=0 to the average visibility value for that item type. 
sales_df.loc[missing_visibility_filter, 'Item_Visibility'] = sales_df.loc[missing_visibility_filter, 'Item_Identifier'].apply(lambda x: average_visibility[x])

# %%
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Notice that the Item_Identifier column contains many categories, some of which do not have very many examples (instances) in the dataset. 
# 
# Combine the Item_Identifier column into broader categories, using the fact that the first two letters in each item identifier
# point to which category the item falls into (FD = Food, DR = Drink, NC = Non-Consumeable).
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Create a new column "Item_Type_Binned" that contains the first two characters in the Item_Identifier string.
sales_df['Item_Id_Binned'] = sales_df['Item_Identifier'].apply(lambda x : x[0:2])


# Expand the two letter code in the "Item_Type_Binned" column (created above) into a more obvious category name.
sales_df['Item_Id_Binned'] = sales_df['Item_Id_Binned'].map({'FD' : 'Food', 'NC' : 'Non-Consumable', 'DR' : 'Drinks'})

# %%
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Consider that "Years of operation" may have more of a relationship with sales than "Establishment_year".
#
# For perspective, both of these features would be ordinal (an ordering exists both amongst years established and years of operation), however an ordinal encoder would
# default to giving the oldest store the smallest numeric value (1985 = 0) if the "Establishment_year" feature is used. If the "years of operation" feature is used,
# now the oldest store has the largest value, and as such an ordinal encoder would then give the oldest store the largest numeric value. This difference may be subtle
# but could affect the way a ML algorithm fits a model to these features. 
#
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Create a new column 'Years of operation' that equals the number of years prior to 2013 that this store was established.
sales_df['Years_of_operation'] = 2013 - sales_df['Outlet_Establishment_Year']

# %%
# Make category names in the Item_Fat_Content feature consistent.
sales_df['Item_Fat_Content'] = sales_df['Item_Fat_Content'].replace({'LF' : 'Low Fat', 'reg' : 'Regular', 'low fat' : 'Low Fat'})

# %%
# Some "Non-Consumable" item types have a fat content listed. For all "Non-Consumable" items, change the fat content value to 
# a new category called "Not_Edible".
sales_df.loc[sales_df['Item_Id_Binned'] == 'Non-Consumable', 'Item_Fat_Content'] = 'Not_Edible'

# %% [markdown]
# #Imputing

# %%
# -------------------------------------------------------------------------------------------------------------------------
# Imputing the missing weight values using the average item weight for that item type. 
# -------------------------------------------------------------------------------------------------------------------------

# Create groups of each unique item identifier. For each group, calculate the average item weight.
average_weight_per_item = sales_df.groupby(by="Item_Identifier")['Item_Weight'].mean()

# Create a filter to easily grab all the rows where the Item_Weight value is missing.
missing_weight_filter = (sales_df['Item_Weight'].isna())

# Set each missing Item_Weight equal to the average item weight for that Item_Identifier.
# For example, for item 'DRA24' the weight value with be mapped to average_weight_per_item['DRA24'], which is 19.35 per the averages we calculated two lines above.
sales_df.loc[missing_weight_filter, 'Item_Weight'] = sales_df.loc[missing_weight_filter, 'Item_Identifier'].apply(lambda Item_ID : average_weight_per_item[Item_ID] )

# %%
# -------------------------------------------------------------------------------------------------------------------------
# Imputing the missing Outlet_Size values with the mode (most frequent) outlet size value for that outlet type.
# -------------------------------------------------------------------------------------------------------------------------

# Create groups for each unique value of Outlet_Type. For each outlet_type group, calculate the most frequent outlet_size. 
most_frequent_size_per_type = sales_df.groupby(by="Outlet_Type")['Outlet_Size'].agg(pd.Series.mode)

# Create a filter for easily accessing all the rows where the Outlet_Size value is missing.
missing_outlet_size = sales_df['Outlet_Size'].isna()

# impute the missing values in the Outlet_Size column with the most frequent Outlet_Size for that Outlet_Type
sales_df.loc[missing_outlet_size, 'Outlet_Size'] = sales_df.loc[missing_outlet_size, 'Outlet_Type'].apply(lambda store_type : most_frequent_size_per_type[store_type])

# %%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------
# There are still four missing values in the Item_Weight column. This is because we imputed the missing Item_Weight values using the average weight per item type, and 
# it turns out for these four items there is only a single instance of that item type, therefore no other information existed to compute an average from! 
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------

sales_df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  4
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Item_Id_Binned               0
# Years_of_operation           0
# dtype: int64

# %%
# Impute the four remaining missing Item_Weight values using the average Item_Weight for that Item_Type. 
average_weights_per_type = sales_df.groupby('Item_Type')['Item_Weight'].mean()

# Filter to easily select the four rows that still have missing Item_Weight values.
missing_weights = sales_df['Item_Weight'].isna()

# Imputing the four remaining missing Item_Weight values with the average weight value for that item type. 
sales_df.loc[missing_weights, 'Item_Weight'] = sales_df.loc[missing_weights, 'Item_Type'].apply(lambda item_type : average_weights_per_type[item_type])

# %%
sales_df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# Item_Id_Binned               0
# Years_of_operation           0
# dtype: int64

# %%
filepath = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/Sales_Training_Data_Cleaned_Imputed.csv'

sales_df.to_csv(path_or_buf=filepath, index=False)

sales_df.drop(columns=['Item_Identifier', 'Outlet_Establishment_Year'], inplace=True)

# %%
'''
nominal_categorical_feat = ['Item_Type', 'Outlet_Identifier', 'Outlet_Location_Type', 'Outlet_Type', 'Item_Id_Binned']
ordinal_categorical_feat = ['Item_Fat_Content', 'Outlet_Size', 'Years_of_operation']
numeric_feat = ['Item_Weight', 'Item_Visibility', 'Item_MRP']

X = sales_df.loc[:, sales_df.columns != 'Item_Outlet_Sales']
y = sales_df.loc[:, 'Item_Outlet_Sales']

preprocess = ColumnTransformer(transformers=[("std_scaler", StandardScaler(), numeric_feat),
                                             ("one_hot_encoder", OneHotEncoder(drop="first", sparse=False), nominal_categorical_feat),
                                             ("ordinal_encoder", OrdinalEncoder(), ordinal_categorical_feat)],
                               remainder='passthrough')


num_trees = [1, 5, 10, 50, 100, 150, 200]
max_depth = [None, 7]

column_list = list(range(5,38))
num_neighbors = list(range(1, 26))

random_forest = RandomForestRegressor(random_state=42, oob_score=True)
bagged_trees = BaggingRegressor(random_state=42, oob_score=True)

reg_strategy = TransformedTargetRegressor()
bcox_transformer = PowerTransformer(method='box-cox')

model_pipeline = Pipeline([("preprocessing", preprocess),
                           ('feature_selector', SelectKBest(f_regression)),
                           ('regress', reg_strategy)])

# -----------------------------------------------------------------------------------------------------------------------------------------------
# The dictionary key with double unscore (feature_selector__K) is a special syntax that allows us tell GridSearch to vary the "k" parameter
# of the object named "feature_selector" (which in our case is a SelectKBest object) when search for the best set of parameters.
# -----------------------------------------------------------------------------------------------------------------------------------------------
parameter_grid = [{'feature_selector__k': column_list,
                   'regress__regressor' : [bagged_trees],           
                   'regress__regressor__n_estimators' : num_trees,
                   'regress__regressor__base_estimator' : [DecisionTreeRegressor()],
                   'regress__regressor__base_estimator__max_depth' : max_depth,  
                   'regress__transformer' : [None, bcox_transformer]},
                  {'feature_selector__k': column_list,                       
                   'regress__regressor' : [random_forest],           
                   'regress__regressor__n_estimators' : num_trees,
                   'regress__regressor__max_depth' : max_depth,  
                   'regress__transformer' : [None, bcox_transformer]},
                  {'feature_selector__k' : column_list,                         # Linear Regression with all possible numbers of "best features" evaluted.
                   'regress__regressor' : [LinearRegression(), Lasso()],         # Target is box-cox transformed to zero mean and unit variance
                   'regress__transformer' : [None, bcox_transformer]},
                  {'feature_selector__k' : column_list,                     # Same as above, only difference is the target is target is scaled using box-cox
                   'regress__regressor' : [KNeighborsRegressor()],
                   'regress__regressor__n_neighbors' : num_neighbors,
                   'regress__regressor__weights' : ['uniform', 'distance'],
                   'regress__transformer' : [None, bcox_transformer]}]



score_types = {'r2' :'r2', 'MSE' : 'neg_mean_squared_error'}

gs = GridSearchCV(estimator=model_pipeline, param_grid=parameter_grid, scoring=score_types, refit='MSE', cv=5, n_jobs=-1)

gs.fit(X, y)

PATH = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/'
gridsearch_result_filename = 'gridsearch_models_2.pkl'
full_path = PATH + gridsearch_result_filename
with open(full_path, 'wb') as file:
  pickle.dump(gs, file)
'''
# Out:
# '\nnominal_categorical_feat = [\'Item_Type\', \'Outlet_Identifier\', \'Outlet_Location_Type\', \'Outlet_Type\', \'Item_Id_Binned\']\nordinal_categorical_feat = [\'Item_Fat_Content\', \'Outlet_Size\', \'Years_of_operation\']\nnumeric_feat = [\'Item_Weight\', \'Item_Visibility\', \'Item_MRP\']\n\nX = sales_df.loc[:, sales_df.columns != \'Item_Outlet_Sales\']\ny = sales_df.loc[:, \'Item_Outlet_Sales\']\n\npreprocess = ColumnTransformer(transformers=[("std_scaler", StandardScaler(), numeric_feat),\n                                             ("one_hot_encoder", OneHotEncoder(drop="first", sparse=False), nominal_categorical_feat),\n                                             ("ordinal_encoder", OrdinalEncoder(), ordinal_categorical_feat)],\n                               remainder=\'passthrough\')\n\n\nnum_trees = [1, 5, 10, 50, 100, 150, 200]\nmax_depth = [None, 7]\n\ncolumn_list = list(range(5,38))\nnum_neighbors = list(range(1, 26))\n\nrandom_forest = RandomForestRegressor(random_state=42, oob_score=True)\nbagged_trees = BaggingRegressor(random_state=42, oob_score=True)\n\nreg_strategy = TransformedTargetRegressor()\nbcox_transformer = PowerTransformer(method=\'box-cox\')\n\nmodel_pipeline = Pipeline([("preprocessing", preprocess),\n                           (\'feature_selector\', SelectKBest(f_regression)),\n                           (\'regress\', reg_strategy)])\n\n# -----------------------------------------------------------------------------------------------------------------------------------------------\n# The dictionary key with double unscore (feature_selector__K) is a special syntax that allows us tell GridSearch to vary the "k" parameter\n# of the object named "feature_selector" (which in our case is a SelectKBest object) when search for the best set of parameters.\n# -----------------------------------------------------------------------------------------------------------------------------------------------\nparameter_grid = [{\'feature_selector__k\': column_list,\n                   \'regress__regressor\' : [bagged_trees],           \n                   \'regress__regressor__n_estimators\' : num_trees,\n                   \'regress__regressor__base_estimator\' : [DecisionTreeRegressor()],\n                   \'regress__regressor__base_estimator__max_depth\' : max_depth,  \n                   \'regress__transformer\' : [None, bcox_transformer]},\n                  {\'feature_selector__k\': column_list,                       \n                   \'regress__regressor\' : [random_forest],           \n                   \'regress__regressor__n_estimators\' : num_trees,\n                   \'regress__regressor__max_depth\' : max_depth,  \n                   \'regress__transformer\' : [None, bcox_transformer]},\n                  {\'feature_selector__k\' : column_list,                         # Linear Regression with all possible numbers of "best features" evaluted.\n                   \'regress__regressor\' : [LinearRegression(), Lasso()],         # Target is box-cox transformed to zero mean and unit variance\n                   \'regress__transformer\' : [None, bcox_transformer]},\n                  {\'feature_selector__k\' : column_list,                     # Same as above, only difference is the target is target is scaled using box-cox\n                   \'regress__regressor\' : [KNeighborsRegressor()],\n                   \'regress__regressor__n_neighbors\' : num_neighbors,\n                   \'regress__regressor__weights\' : [\'uniform\', \'distance\'],\n                   \'regress__transformer\' : [None, bcox_transformer]}]\n\n\n\nscore_types = {\'r2\' :\'r2\', \'MSE\' : \'neg_mean_squared_error\'}\n\ngs = GridSearchCV(estimator=model_pipeline, param_grid=parameter_grid, scoring=score_types, refit=\'MSE\', cv=5, n_jobs=-1)\n\ngs.fit(X, y)\n\nPATH = \'/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/\'\ngridsearch_result_filename = \'gridsearch_models_2.pkl\'\nfull_path = P ...

# %%
full_path = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/gridsearch_models_2.pkl'

with open(full_path, 'rb') as file:
  gs_results = pickle.load(file)

search_results = gs_results.cv_results_
top_estimator = gs_results.best_estimator_
top_score = gs_results.best_score_
top_parameters = gs_results.best_params_

# %%
top_parameters
# Out:
# {'feature_selector__k': 34,
#  'regress__regressor': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                        max_depth=7, max_features='auto', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=True,
#                        random_state=42, verbose=0, warm_start=False),
#  'regress__regressor__max_depth': 7,
#  'regress__regressor__n_estimators': 100,
#  'regress__transformer': None}

# %%
gs_result_df = pd.DataFrame(search_results)

list(gs_result_df.columns)
# Out:
# ['mean_fit_time',
#  'std_fit_time',
#  'mean_score_time',
#  'std_score_time',
#  'param_feature_selector__k',
#  'param_regress__regressor',
#  'param_regress__regressor__base_estimator',
#  'param_regress__regressor__base_estimator__max_depth',
#  'param_regress__regressor__n_estimators',
#  'param_regress__transformer',
#  'param_regress__regressor__max_depth',
#  'param_regress__regressor__n_neighbors',
#  'param_regress__regressor__weights',
#  'params',
#  'split0_test_r2',
#  'split1_test_r2',
#  'split2_test_r2',
#  'split3_test_r2',
#  'split4_test_r2',
#  'mean_test_r2',
#  'std_test_r2',
#  'rank_test_r2',
#  'split0_test_MSE',
#  'split1_test_MSE',
#  'split2_test_MSE',
#  'split3_test_MSE',
#  'split4_test_MSE',
#  'mean_test_MSE',
#  'std_test_MSE',
#  'rank_test_MSE']

# %%
#------------------------------------------------------------------------------------------------------------------------------------------------
# Perform Data Cleaning on the GridSearchCV output
#------------------------------------------------------------------------------------------------------------------------------------------------

gs_result_df = pd.DataFrame(search_results)

results_simplified_df= gs_result_df.loc[:,:].sort_values(by=['rank_test_MSE'], ignore_index=True)

results_simplified_df.rename(columns= {'param_feature_selector__k' : 'num_features_in_model',
                                       'param_regress__regressor' : 'model_type',
                                       'param_regress__transformer' : 'target_transformation',
                                       'param_regress__regressor__n_neighbors' : "Num_Nearest_Neighbors",
                                       'param_regress__regressor__weights' : "Neighbors_Score_Strategy",
                                       'param_regress__regressor__max_depth' : 'rand_forest_max_depth',
                                       'param_regress__regressor__n_estimators' : 'Number_of_Trees',
                                       'param_regress__regressor__base_estimator__max_depth' : 'bagged_tree_max_depth'}, inplace=True)

results_simplified_df = results_simplified_df.loc[:, ['num_features_in_model', 'model_type', 'target_transformation', 'Num_Nearest_Neighbors',
                                                      'Neighbors_Score_Strategy', 'rand_forest_max_depth', 'Number_of_Trees', 'bagged_tree_max_depth',
                                                      'mean_test_r2', 'rank_test_r2', 'mean_test_MSE', 'rank_test_MSE']]

# For easier viewing, combine 'rand_forest_max_depth' and 'bagged_tree_max_depth" into a single column called "tree_depth".
results_simplified_df['tree_depth'] = results_simplified_df['rand_forest_max_depth'].fillna(value=results_simplified_df['bagged_tree_max_depth'])
results_simplified_df['tree_depth'] = results_simplified_df['tree_depth'].fillna(value='No_Limit')
results_simplified_df.drop(columns=['rand_forest_max_depth', 'bagged_tree_max_depth'], inplace=True)

# Indicate if the model recieved a 'Box-cox' transformation of the target variable, or if not then list 'No_transformation'.
results_simplified_df['target_transformation'] = results_simplified_df['target_transformation'].fillna(value="No_Transformation")
results_simplified_df.loc[ (results_simplified_df['target_transformation'] != 'No_Transformation') , 'target_transformation'] = "Box-Cox"

# For easier viewing, trim model_type down so it only shows the name of the model used.
results_simplified_df['model_type'] = results_simplified_df['model_type'].astype(str)
results_simplified_df['model_type'] = results_simplified_df['model_type'].map(lambda model_string : model_string.split('(')[0])

results_simplified_df['Num_Nearest_Neighbors'] = results_simplified_df['Num_Nearest_Neighbors'].fillna(value='Not_Applicable')
results_simplified_df['Neighbors_Score_Strategy'] = results_simplified_df['Neighbors_Score_Strategy'].fillna(value='Not_Applicable')
results_simplified_df['Number_of_Trees'] = results_simplified_df['Number_of_Trees'].fillna(value='Not_Applicable')

# Negative MSE is not very interpretable. Take the absolute value and square root to get a more meaningful number. 
results_simplified_df['RMSE'] = results_simplified_df['mean_test_MSE'].abs().pow(1./2)

pd.set_option('display.max_rows', 500)

results_simplified_df.head(500)
# Out:
#     num_features_in_model             model_type  ... tree_depth         RMSE
# 0                      34  RandomForestRegressor  ...          7  1085.338347
# 1                      34  RandomForestRegressor  ...          7  1085.479227
# 2                      34  RandomForestRegressor  ...          7  1085.510267
# 3                      37  RandomForestRegressor  ...          7  1085.529219
# 4                      31  RandomForestRegressor  ...          7  1085.531324
# 5                      33  RandomForestRegressor  ...          7  1085.570219
# 6                      33  RandomForestRegressor  ...          7  1085.609329
# 7                      33       BaggingRegressor  ...          7  1085.625256
# 8                      33  RandomForestRegressor  ...          7  1085.633460
# 9                      37  RandomForestRegressor  ...          7  1085.659491
# 10                     33       BaggingRegressor  ...          7  1085.666028
# 11                     37  RandomForestRegressor  ...          7  1085.666174
# 12                     31       BaggingRegressor  ...          7  1085.679364
# 13                     34       BaggingRegressor  ...          7  1085.704201
# 14                     31  RandomForestRegressor  ...          7  1085.715613
# 15                     32  RandomForestRegressor  ...          7  1085.717222
# 16                     36       BaggingRegressor  ...          7  1085.724682
# 17                     32  RandomForestRegressor  ...          7  1085.725001
# 18                     36       BaggingRegressor  ...          7  1085.738260
# 19                     31  RandomForestRegressor  ...          7  1085.756330
# 20                     36       BaggingRegressor  ...          7  1085.764094
# 21                     34       BaggingRegressor  ...          7  1085.774794
# 22                     33       BaggingRegressor  ...          7  1085.779059
# 23                     34       BaggingRegressor  ...          7  1085.781119
# 24                     31       BaggingRegressor  ...          7  1085.782041
# 25                     32  RandomForestRegressor  ...          7  1085.785492
# 26                     35  RandomForestRegressor  ...          7  1085.818236
# 27                     35  RandomForestRegressor  ...          7  1085.826492
# 28                     32       BaggingRegressor  ...          7  1085.839331
# 29                     37       BaggingRegressor  ...          7  1085.839535
# 30                     35  RandomForestRegressor  ...          7  1085.844967
# 31                     32       BaggingRegressor  ...          7  1085.845409
# 32                     32       BaggingRegressor  ...          7  1085.873404
# 33                     37       BaggingRegressor  ...          7  1085.875544
# 34                     30  RandomForestRegressor  ...          7  1085.880150
# 35                     31       BaggingRegressor  ...          7  1085.900878
# 36                     36  RandomForestRegressor  ...          7  1085.933530
# 37                     36  RandomForestRegressor  ...          7  1085.937645
# 38                     37       BaggingRegressor  ...          7  1085.942897
# 39                     35       BaggingRegressor  ...          7  1085.960883
# 40                     36  RandomForestRegressor  ...          7  1085.969683
# 41                     35       BaggingRegressor  ...          7  1086.017496
# 42                     35       BaggingRegressor  ...          7  1086.043104
# 43                     37  RandomForestRegressor  ...          7  1086.075934
# 44                     30  RandomForestRegressor  ...          7  1086.078455
# 45                     29  RandomForestRegressor  ...          7  1086.085071
# 46                     30  RandomForestRegressor  ...          7  1086.112435
# 47                     29       BaggingRegressor  ...          7  1086.182639
# 48                     33       BaggingRegressor  ...          7  1086.210142
# 49                     30       BaggingRegressor  ...          7  1086.231875
# 50                     31  RandomForestRegressor  ...          7  1086.241153
# 51                     29  RandomForestRegressor  ...          7  1086.267681
# 52                     27       BaggingRegressor  ...          7  1086.285086
# 53                     34  RandomForestRegressor  ...          7  1086.308951
# 54                     27  RandomForestRegressor  ...          7  1086.315987
# 55                     30       BaggingRegressor  ...          7  1086.332429
# 56                     28       BaggingRegressor  ...          7  1086.344987
# 57                     34       BaggingRegressor  ...          7  1086.356171
# 58                     28  RandomForestRegressor  ...          7  1086.357950
# 59                     33  RandomForestRegressor  ...          7  1086.367101
# 60                     29  RandomForestRegressor  ...          7  1086.387065
# 61                     10       BaggingRegressor  ...          7  1086.417234
# 62                     30  RandomForestRegressor  ...          7  1086.441863
# 63                     27  RandomForestRegressor  ...          7  1086.453539
# 64                     37       BaggingRegressor  ...          7  1086.455934
# 65                      7       BaggingRegressor  ...          7  1086.474835
# 66                     27  RandomForestRegressor  ...          7  1086.475088
# 67                     27       BaggingRegressor  ...          7  1086.477226
# 68                     30       BaggingRegressor  ...          7  1086.482247
# 69                     28       BaggingRegressor  ...          7  1086.497511
# 70                     11  RandomForestRegressor  ...          7  1086.502405
# 71                     29       BaggingRegressor  ...          7  1086.503116
# 72                     28       BaggingRegressor  ...          7  1086.508145
# 73                     36  RandomForestRegressor  ...          7  1086.515693
# 74                      7       BaggingRegressor  ...          7  1086.516925
# 75                     32  RandomForestRegressor  ...          7  1086.518340
# 76                     10  RandomForestRegressor  ...          7  1086.519843
# 77                     10       BaggingRegressor  ...          7  1086.534424
# 78                     29       BaggingRegressor  ...          7  1086.539828
# 79                     10  RandomForestRegressor  ...          7  1086.547013
# 80                      9       BaggingRegressor  ...          7  1086.549026
# 81                     27  RandomForestRegressor  ...          7  1086.552467
# 82                      7  RandomForestRegressor  ...          7  1086.557376
# 83                      7  RandomForestRegressor  ...          7  1086.558016
# 84                     28  RandomForestRegressor  ...          7  1086.562405
# 85                     27       BaggingRegressor  ...          7  1086.586900
# 86                     28  RandomForestRegressor  ...          7  1086.596452
# 87                     31       BaggingRegressor  ...          7  1086.603821
# 88                     27       BaggingRegressor  ...          7  1086.611898
# 89                      9       BaggingRegressor  ...          7  1086.617624
# 90                      9  RandomForestRegressor  ...          7  1086.634681
# 91                      9  RandomForestRegressor  ...          7  1086.639850
# 92                     35  RandomForestRegressor  ...          7  1086.651229
# 93                     28  RandomForestRegressor  ...          7  1086.698011
# 94                     11       BaggingRegressor  ...          7  1086.717355
# 95                     32       BaggingRegressor  ...          7  1086.723568
# 96                     10       BaggingRegressor  ...          7  1086.749176
# 97                      8       BaggingRegressor  ...          7  1086.764961
# 98                     10  RandomForestRegressor  ...          7  1086.787357
# 99                     36       BaggingRegressor  ...          7  1086.796865
# 100                    25       BaggingRegressor  ...          7  1086.808878
# 101                    12       BaggingRegressor  ...          7  1086.848068
# 102                     7       BaggingRegressor  ...          7  1086.855990
# 103                     7       BaggingRegressor  ...          7  1086.860553
# 104                    35       BaggingRegressor  ...          7  1086.874907
# 105                     8  RandomForestRegressor  ...          7  1086.877154
# 106                     9  RandomForestRegressor  ...          7  1086.900985
# 107                    11  RandomForestRegressor  ...          7  1086.901534
# 108                    25       BaggingRegressor  ...          7  1086.901729
# 109                     8       BaggingRegressor  ...          7  1086.903055
# 110                     7  RandomForestRegressor  ...          7  1086.908023
# 111                    25  RandomForestRegressor  ...          7  1086.909766
# 112                     9       BaggingRegressor  ...          7  1086.918306
# 113                    11       BaggingRegressor  ...          7  1086.920839
# 114                    29  RandomForestRegressor  ...          7  1086.937291
# 115                    26  RandomForestRegressor  ...          7  1086.952556
# 116                     7  RandomForestRegressor  ...          7  1086.956684
# 117                    30       BaggingRegressor  ...          7  1086.961360
# 118                     9  RandomForestRegressor  ...          7  1086.989944
# 119                     9       BaggingRegressor  ...          7  1087.001116
# 120                    25  RandomForestRegressor  ...          7  1087.003802
# 121                    11  RandomForestRegressor  ...          7  1087.008409
# 122                    10  RandomForestRegressor  ...          7  1087.025921
# 123                    10       BaggingRegressor  ...          7  1087.034003
# 124                     8  RandomForestRegressor  ...          7  1087.035014
# 125                    26  RandomForestRegressor  ...          7  1087.059718
# 126                    11       BaggingRegressor  ...          7  1087.065297
# 127                    25       BaggingRegressor  ...          7  1087.077875
# 128                    29       BaggingRegressor  ...          7  1087.081582
# 129                    28       BaggingRegressor  ...          7  1087.082281
# 130                    25       BaggingRegressor  ...          7  1087.090616
# 131                     8       BaggingRegressor  ...          7  1087.150915
# 132                    26       BaggingRegressor  ...          7  1087.175874
# 133                     8  RandomForestRegressor  ...          7  1087.199917
# 134                    25  RandomForestRegressor  ...          7  1087.217996
# 135                    12       BaggingRegressor  ...          7  1087.228097
# 136                    26  RandomForestRegressor  ...          7  1087.231927
# 137                    26       BaggingRegressor  ...          7  1087.239079
# 138                    12  RandomForestRegressor  ...          7  1087.243685
# 139                    11  RandomForestRegressor  ...          7  1087.253810
# 140                    26  RandomForestRegressor  ...          7  1087.259668
# 141                    26       BaggingRegressor  ...          7  1087.262556
# 142                    11       BaggingRegressor  ...          7  1087.267218
# 143                     8  RandomForestRegressor  ...          7  1087.271920
# 144                    26       BaggingRegressor  ...          7  1087.272610
# 145                    25  RandomForestRegressor  ...          7  1087.282682
# 146                     8       BaggingRegressor  ...          7  1087.293343
# 147                    12       BaggingRegressor  ...          7  1087.297077
# 148                    12  RandomForestRegressor  ...          7  1087.325037
# 149                    12  RandomForestRegressor  ...          7  1087.527024
# 150                    15       BaggingRegressor  ...          7  1087.605746
# 151                    19       BaggingRegressor  ...          7  1087.608667
# 152                    12       BaggingRegressor  ...          7  1087.627961
# 153                    20       BaggingRegressor  ...          7  1087.640618
# 154                    21       BaggingRegressor  ...          7  1087.684967
# 155                    12  RandomForestRegressor  ...          7  1087.770028
# 156                    18       BaggingRegressor  ...          7  1087.770850
# 157                    20  RandomForestRegressor  ...          7  1087.776475
# 158                    18  RandomForestRegressor  ...          7  1087.785240
# 159                    19  RandomForestRegressor  ...          7  1087.805749
# 160                    14       BaggingRegressor  ...          7  1087.826558
# 161                    16       BaggingRegressor  ...          7  1087.869594
# 162                    17       BaggingRegressor  ...          7  1087.875401
# 163                    13  RandomForestRegressor  ...          7  1087.898388
# 164                    14  RandomForestRegressor  ...          7  1087.899300
# 165                    14       BaggingRegressor  ...          7  1087.934377
# 166                    15  RandomForestRegressor  ...          7  1087.954830
# 167                    13       BaggingRegressor  ...          7  1087.958120
# 168                    22       BaggingRegressor  ...          7  1087.965671
# 169                    13  RandomForestRegressor  ...          7  1088.039700
# 170                    21  RandomForestRegressor  ...          7  1088.046361
# 171                    13       BaggingRegressor  ...          7  1088.086104
# 172                    23  RandomForestRegressor  ...          7  1088.087004
# 173                    14  RandomForestRegressor  ...          7  1088.092495
# 174                    14       BaggingRegressor  ...          7  1088.104311
# 175                    14  RandomForestRegressor  ...          7  1088.105734
# 176                    13  RandomForestRegressor  ...          7  1088.135878
# 177                    16  RandomForestRegressor  ...          7  1088.160697
# 178                    16       BaggingRegressor  ...          7  1088.178682
# 179                    24       BaggingRegressor  ...          7  1088.211052
# 180                    15       BaggingRegressor  ...          7  1088.212079
# 181                    13       BaggingRegressor  ...          7  1088.225966
# 182                    15  RandomForestRegressor  ...          7  1088.228379
# 183                    15       BaggingRegressor  ...          7  1088.229078
# 184                    16       BaggingRegressor  ...          7  1088.247262
# 185                    19  RandomForestRegressor  ...          7  1088.252073
# 186                    19       BaggingRegressor  ...          7  1088.259150
# 187                    17  RandomForestRegressor  ...          7  1088.270603
# 188                    24       BaggingRegressor  ...          7  1088.285788
# 189                    19       BaggingRegressor  ...          7  1088.300576
# 190                    13  RandomForestRegressor  ...          7  1088.308650
# 191                    16  RandomForestRegressor  ...          7  1088.309673
# 192                    14  RandomForestRegressor  ...          7  1088.326225
# 193                    18  RandomForestRegressor  ...          7  1088.329971
# 194                    16  RandomForestRegressor  ...          7  1088.354231
# 195                    18  RandomForestRegressor  ...          7  1088.355710
# 196                    17       BaggingRegressor  ...          7  1088.367898
# 197                    13       BaggingRegressor  ...          7  1088.373615
# 198                    18       BaggingRegressor  ...          7  1088.374955
# 199                    24       BaggingRegressor  ...          7  1088.380082
# 200                    14       BaggingRegressor  ...          7  1088.382530
# 201                    15  RandomForestRegressor  ...          7  1088.385104
# 202                    17  RandomForestRegressor  ...          7  1088.389754
# 203                    19  RandomForestRegressor  ...          7  1088.408497
# 204                    22  RandomForestRegressor  ...          7  1088.416903
# 205                    17       BaggingRegressor  ...          7  1088.421637
# 206                    21       BaggingRegressor  ...          7  1088.444307
# 207                    21       BaggingRegressor  ...          7  1088.449129
# 208                    20  RandomForestRegressor  ...          7  1088.468783
# 209                    20       BaggingRegressor  ...          7  1088.489295
# 210                    20       BaggingRegressor  ...          7  1088.494371
# 211                    20  RandomForestRegressor  ...          7  1088.495965
# 212                    23       BaggingRegressor  ...          7  1088.531589
# 213                    24  RandomForestRegressor  ...          7  1088.562105
# 214                    23  RandomForestRegressor  ...          7  1088.566627
# 215                    17  RandomForestRegressor  ...          7  1088.582208
# 216                    23  RandomForestRegressor  ...          7  1088.605698
# 217                    23       BaggingRegressor  ...          7  1088.624244
# 218                    21  RandomForestRegressor  ...          7  1088.633249
# 219                    18       BaggingRegressor  ...          7  1088.639351
# 220                    24  RandomForestRegressor  ...          7  1088.663568
# 221                    21  RandomForestRegressor  ...          7  1088.693689
# 222                    16       BaggingRegressor  ...          7  1088.704405
# 223                    23       BaggingRegressor  ...          7  1088.709231
# 224                    24  RandomForestRegressor  ...          7  1088.712808
# 225                    19  RandomForestRegressor  ...          7  1088.732402
# 226                    24       BaggingRegressor  ...          7  1088.737188
# 227                    15  RandomForestRegressor  ...          7  1088.756924
# 228                    16  RandomForestRegressor  ...          7  1088.758776
# 229                    15       BaggingRegressor  ...          7  1088.767720
# 230                    19       BaggingRegressor  ...          7  1088.791248
# 231                    18  RandomForestRegressor  ...          7  1088.824914
# 232                    21       BaggingRegressor  ...          7  1088.853574
# 233                    22       BaggingRegressor  ...          7  1088.869343
# 234                    18       BaggingRegressor  ...          7  1088.873703
# 235                    24  RandomForestRegressor  ...          7  1088.888895
# 236                    17       BaggingRegressor  ...          7  1088.903038
# 237                    20  RandomForestRegressor  ...          7  1088.905244
# 238                    17  RandomForestRegressor  ...          7  1088.918844
# 239                    22       BaggingRegressor  ...          7  1088.919064
# 240                    20       BaggingRegressor  ...          7  1088.923792
# 241                    21  RandomForestRegressor  ...          7  1089.030066
# 242                    23  RandomForestRegressor  ...          7  1089.043024
# 243                    22  RandomForestRegressor  ...          7  1089.059029
# 244                    23       BaggingRegressor  ...          7  1089.098946
# 245                    22  RandomForestRegressor  ...          7  1089.101687
# 246                    22       BaggingRegressor  ...          7  1089.266308
# 247                    22  RandomForestRegressor  ...          7  1089.368634
# 248                    27  RandomForestRegressor  ...          7  1090.331410
# 249                    37       BaggingRegressor  ...          7  1090.599140
# 250                    11       BaggingRegressor  ...          7  1090.662707
# 251                    36       BaggingRegressor  ...          7  1090.683369
# 252                    34  RandomForestRegressor  ...          7  1090.699326
# 253                    36  RandomForestRegressor  ...          7  1090.730208
# 254                    33       BaggingRegressor  ...          7  1090.785577
# 255                    10       BaggingRegressor  ...          7  1090.800539
# 256                     7  RandomForestRegressor  ...          7  1090.811942
# 257                    37  RandomForestRegressor  ...          7  1090.867011
# 258                     8       BaggingRegressor  ...          7  1090.868859
# 259                     7       BaggingRegressor  ...          7  1090.884651
# 260                    33  RandomForestRegressor  ...          7  1090.929934
# 261                    27       BaggingRegressor  ...          7  1090.933363
# 262                    25  RandomForestRegressor  ...          7  1090.955217
# 263                    35  RandomForestRegressor  ...          7  1090.963497
# 264                    25       BaggingRegressor  ...          7  1090.970606
# 265                     9  RandomForestRegressor  ...          7  1090.990704
# 266                    10  RandomForestRegressor  ...          7  1090.996679
# 267                    34       BaggingRegressor  ...          7  1091.119493
# 268                     9       BaggingRegressor  ...          7  1091.206429
# 269                    35       BaggingRegressor  ...          7  1091.246421
# 270                     8  RandomForestRegressor  ...          7  1091.283381
# 271                    32  RandomForestRegressor  ...          7  1091.404578
# 272                    31       BaggingRegressor  ...          7  1091.412545
# 273                    31  RandomForestRegressor  ...          7  1091.423448
# 274                    11  RandomForestRegressor  ...          7  1091.425155
# 275                    12       BaggingRegressor  ...          7  1091.479156
# 276                    29       BaggingRegressor  ...          7  1091.498468
# 277                    26  RandomForestRegressor  ...          7  1091.576807
# 278                    28       BaggingRegressor  ...          7  1091.620737
# 279                    30       BaggingRegressor  ...          7  1091.652520
# 280                    32       BaggingRegressor  ...          7  1091.662266
# 281                    26       BaggingRegressor  ...          7  1091.831416
# 282                    30  RandomForestRegressor  ...          7  1091.903893
# 283                    29  RandomForestRegressor  ...          7  1091.905644
# 284                    23       BaggingRegressor  ...          7  1092.004174
# 285                    19       BaggingRegressor  ...          7  1092.034472
# 286                    12  RandomForestRegressor  ...          7  1092.118467
# 287                    28  RandomForestRegressor  ...          7  1092.246149
# 288                    23  RandomForestRegressor  ...          7  1092.540665
# 289                    20  RandomForestRegressor  ...          7  1092.573593
# 290                    15       BaggingRegressor  ...          7  1092.695761
# 291                    17       BaggingRegressor  ...          7  1092.730528
# 292                    19  RandomForestRegressor  ...          7  1092.808088
# 293                    14       BaggingRegressor  ...          7  1092.908381
# 294                    21  RandomForestRegressor  ...          7  1092.947706
# 295                    20       BaggingRegressor  ...          7  1093.015626
# 296                    24       BaggingRegressor  ...          7  1093.034453
# 297                    21       BaggingRegressor  ...          7  1093.054054
# 298                    13       BaggingRegressor  ...          7  1093.172096
# 299                    22  RandomForestRegressor  ...          7  1093.221964
# 300                    18       BaggingRegressor  ...          7  1093.228018
# 301                    18  RandomForestRegressor  ...          7  1093.246764
# 302                    13  RandomForestRegressor  ...          7  1093.261180
# 303                    15  RandomForestRegressor  ...          7  1093.309469
# 304                    22       BaggingRegressor  ...          7  1093.331139
# 305                    16  RandomForestRegressor  ...          7  1093.340916
# 306                    36  RandomForestRegressor  ...          7  1093.346720
# 307                    16       BaggingRegressor  ...          7  1093.403484
# 308                    24  RandomForestRegressor  ...          7  1093.426629
# 309                    14  RandomForestRegressor  ...          7  1093.563707
# 310                    27  RandomForestRegressor  ...          7  1093.681734
# 311                    30       BaggingRegressor  ...          7  1093.794797
# 312                     7    KNeighborsRegressor  ...   No_Limit  1093.807186
# 313                    36       BaggingRegressor  ...          7  1093.836861
# 314                    17  RandomForestRegressor  ...          7  1093.938223
# 315                    27       BaggingRegressor  ...          7  1094.021608
# 316                    33  RandomForestRegressor  ...          7  1094.027687
# 317                    33       BaggingRegressor  ...          7  1094.070474
# 318                    34  RandomForestRegressor  ...          7  1094.112248
# 319                    32  RandomForestRegressor  ...          7  1094.153047
# 320                    30  RandomForestRegressor  ...          7  1094.173985
# 321                    31  RandomForestRegressor  ...          7  1094.206826
# 322                    37       BaggingRegressor  ...          7  1094.213149
# 323                     7    KNeighborsRegressor  ...   No_Limit  1094.288896
# 324                    25       BaggingRegressor  ...          7  1094.368996
# 325                     9  RandomForestRegressor  ...          7  1094.430504
# 326                    31       BaggingRegressor  ...          7  1094.432348
# 327                     8       BaggingRegressor  ...          7  1094.466559
# 328                    32       BaggingRegressor  ...          7  1094.538497
# 329                    11       BaggingRegressor  ...          7  1094.566417
# 330                    37  RandomForestRegressor  ...          7  1094.570057
# 331                    10       BaggingRegressor  ...          7  1094.607250
# 332                    25  RandomForestRegressor  ...          7  1094.695954
# 333                    34       BaggingRegressor  ...          7  1094.775980
# 334                     8  RandomForestRegressor  ...          7  1094.778627
# 335                    35  RandomForestRegressor  ...          7  1094.787118
# 336                    11    KNeighborsRegressor  ...   No_Limit  1094.809883
# 337                    10    KNeighborsRegressor  ...   No_Limit  1094.813317
# 338                    10  RandomForestRegressor  ...          7  1094.827721
# 339                     9       BaggingRegressor  ...          7  1094.850976
# 340                     7  RandomForestRegressor  ...          7  1094.863665
# 341                     7       BaggingRegressor  ...          7  1094.875752
# 342                    28       BaggingRegressor  ...          7  1094.933345
# 343                    29       BaggingRegressor  ...          7  1094.937801
# 344                    26       BaggingRegressor  ...          7  1094.948873
# 345                    35       BaggingRegressor  ...          7  1094.960227
# 346                     7    KNeighborsRegressor  ...   No_Limit  1094.998043
# 347                    11  RandomForestRegressor  ...          7  1095.119131
# 348                    26  RandomForestRegressor  ...          7  1095.151217
# 349                    12       BaggingRegressor  ...          7  1095.281620
# 350                    29  RandomForestRegressor  ...          7  1095.375640
# 351                    20  RandomForestRegressor  ...          7  1095.411957
# 352                    27       BaggingRegressor  ...          7  1095.485037
# 353                    27  RandomForestRegressor  ...          7  1095.495968
# 354                    34       BaggingRegressor  ...          7  1095.529124
# 355                    15       BaggingRegressor  ...          7  1095.531050
# 356                    34  RandomForestRegressor  ...          7  1095.595709
# 357                    35       BaggingRegressor  ...          7  1095.615162
# 358                    19       BaggingRegressor  ...          7  1095.660359
# 359                    24       BaggingRegressor  ...          7  1095.680357
# 360                    30  RandomForestRegressor  ...          7  1095.689830
# 361                    34       BaggingRegressor  ...          7  1095.708392
# 362                    30       BaggingRegressor  ...          7  1095.717270
# 363                    37       BaggingRegressor  ...          7  1095.767793
# 364                    25       BaggingRegressor  ...          7  1095.777037
# 365                    35  RandomForestRegressor  ...          7  1095.781248
# 366                    11       BaggingRegressor  ...          7  1095.783106
# 367                    35       BaggingRegressor  ...          7  1095.785410
# 368                     7       BaggingRegressor  ...          7  1095.788064
# 369                    34  RandomForestRegressor  ...          7  1095.788848
# 370                     7  RandomForestRegressor  ...          7  1095.790414
# 371                    29       BaggingRegressor  ...          7  1095.791745
# 372                    36  RandomForestRegressor  ...          7  1095.794855
# 373                    26  RandomForestRegressor  ...          7  1095.803026
# 374                     7       BaggingRegressor  ...          7  1095.804954
# 375                    26       BaggingRegressor  ...          7  1095.807892
# 376                    28       BaggingRegressor  ...          7  1095.812021
# 377                    36       BaggingRegressor  ...          7  1095.824173
# 378                     7    KNeighborsRegressor  ...   No_Limit  1095.827583
# 379                    37  RandomForestRegressor  ...          7  1095.832352
# 380                    25  RandomForestRegressor  ...          7  1095.836090
# 381                    31  RandomForestRegressor  ...          7  1095.838674
# 382                    10  RandomForestRegressor  ...          7  1095.842539
# 383                    27  RandomForestRegressor  ...          7  1095.844013
# 384                     7  RandomForestRegressor  ...          7  1095.849170
# 385                    10  RandomForestRegressor  ...          7  1095.852509
# 386                     7       BaggingRegressor  ...          7  1095.854722
# 387                    11  RandomForestRegressor  ...          7  1095.867850
# 388                    33       BaggingRegressor  ...          7  1095.873751
# 389                    13       BaggingRegressor  ...          7  1095.876144
# 390                    21  RandomForestRegressor  ...          7  1095.876765
# 391                     7    KNeighborsRegressor  ...   No_Limit  1095.880158
# 392                    31       BaggingRegressor  ...          7  1095.887366
# 393                    11  RandomForestRegressor  ...          7  1095.889468
# 394                    35  RandomForestRegressor  ...          7  1095.893107
# 395                     9       BaggingRegressor  ...          7  1095.896121
# 396                     9    KNeighborsRegressor  ...   No_Limit  1095.896870
# 397                    29  RandomForestRegressor  ...          7  1095.901045
# 398                     7  RandomForestRegressor  ...          7  1095.901432
# 399                    27       BaggingRegressor  ...          7  1095.914145
# 400                    32  RandomForestRegressor  ...          7  1095.916243
# 401                    32       BaggingRegressor  ...          7  1095.916280
# 402                    10       BaggingRegressor  ...          7  1095.916587
# 403                    27       BaggingRegressor  ...          7  1095.928325
# 404                    11       BaggingRegressor  ...          7  1095.928878
# 405                    28  RandomForestRegressor  ...          7  1095.941123
# 406                    37  RandomForestRegressor  ...          7  1095.945488
# 407                    12  RandomForestRegressor  ...          7  1095.963229
# 408                    12  RandomForestRegressor  ...          7  1095.964263
# 409                    11       BaggingRegressor  ...          7  1095.964581
# 410                    30       BaggingRegressor  ...          7  1095.966494
# 411                     7  RandomForestRegressor  ...          7  1095.974536
# 412                     9  RandomForestRegressor  ...          7  1095.976918
# 413                    27  RandomForestRegressor  ...          7  1095.977035
# 414                    31  RandomForestRegressor  ...          7  1095.985296
# 415                    36  RandomForestRegressor  ...          7  1095.987337
# 416                    28  RandomForestRegressor  ...          7  1095.993118
# 417                     9       BaggingRegressor  ...          7  1095.998457
# 418                    30  RandomForestRegressor  ...          7  1096.002008
# 419                    10  RandomForestRegressor  ...          7  1096.004143
# 420                    33       BaggingRegressor  ...          7  1096.016672
# 421                    37       BaggingRegressor  ...          7  1096.021525
# 422                    36       BaggingRegressor  ...          7  1096.022803
# 423                    25       BaggingRegressor  ...          7  1096.024790
# 424                     7       BaggingRegressor  ...          7  1096.027019
# 425                    12       BaggingRegressor  ...          7  1096.040537
# 426                     8  RandomForestRegressor  ...          7  1096.050576
# 427                    28       BaggingRegressor  ...          7  1096.053660
# 428                    25       BaggingRegressor  ...          7  1096.053804
# 429                    33  RandomForestRegressor  ...          7  1096.058241
# 430                    26       BaggingRegressor  ...          7  1096.066144
# 431                    31       BaggingRegressor  ...          7  1096.066177
# 432                     9  RandomForestRegressor  ...          7  1096.089236
# 433                    12  RandomForestRegressor  ...          7  1096.090891
# 434                     8       BaggingRegressor  ...          7  1096.097022
# 435                    25  RandomForestRegressor  ...          7  1096.102721
# 436                    10       BaggingRegressor  ...          7  1096.109878
# 437                    11  RandomForestRegressor  ...          7  1096.113501
# 438                    32       BaggingRegressor  ...          7  1096.120128
# 439                    10  RandomForestRegressor  ...          7  1096.120268
# 440                     8    KNeighborsRegressor  ...   No_Limit  1096.120811
# 441                    11       BaggingRegressor  ...          7  1096.128588
# 442                    12       BaggingRegressor  ...          7  1096.131855
# 443                    26  RandomForestRegressor  ...          7  1096.133903
# 444                    29       BaggingRegressor  ...          7  1096.142751
# 445                    17       BaggingRegressor  ...          7  1096.143789
# 446                     8       BaggingRegressor  ...          7  1096.153426
# 447                    10       BaggingRegressor  ...          7  1096.158509
# 448                     8       BaggingRegressor  ...          7  1096.159004
# 449                    26  RandomForestRegressor  ...          7  1096.160977
# 450                     8  RandomForestRegressor  ...          7  1096.163710
# 451                     9       BaggingRegressor  ...          7  1096.174694
# 452                    26       BaggingRegressor  ...          7  1096.184126
# 453                    32  RandomForestRegressor  ...          7  1096.185079
# 454                     8  RandomForestRegressor  ...          7  1096.193232
# 455                    34       BaggingRegressor  ...          7  1096.197228
# 456                    12       BaggingRegressor  ...          7  1096.198981
# 457                    29  RandomForestRegressor  ...          7  1096.200531
# 458                    11  RandomForestRegressor  ...          7  1096.215128
# 459                    34  RandomForestRegressor  ...          7  1096.232039
# 460                     9  RandomForestRegressor  ...          7  1096.239220
# 461                    15  RandomForestRegressor  ...          7  1096.251021
# 462                    11    KNeighborsRegressor  ...   No_Limit  1096.253295
# 463                    10    KNeighborsRegressor  ...   No_Limit  1096.254664
# 464                    30  RandomForestRegressor  ...          7  1096.254825
# 465                    28  RandomForestRegressor  ...          7  1096.256314
# 466                    25  RandomForestRegressor  ...          7  1096.258345
# 467                    12  RandomForestRegressor  ...          7  1096.259867
# 468                     8  RandomForestRegressor  ...          7  1096.260749
# 469                    26  RandomForestRegressor  ...          7  1096.266490
# 470                    33  RandomForestRegressor  ...          7  1096.273483
# 471                    11    KNeighborsRegressor  ...   No_Limit  1096.278539
# 472                    21       BaggingRegressor  ...          7  1096.290089
# 473                    10    KNeighborsRegressor  ...   No_Limit  1096.293499
# 474                     8       BaggingRegressor  ...          7  1096.295021
# 475                    24  RandomForestRegressor  ...          7  1096.310256
# 476                    14       BaggingRegressor  ...          7  1096.314335
# 477                    35  RandomForestRegressor  ...          7  1096.317611
# 478                     9  RandomForestRegressor  ...          7  1096.319342
# 479                    37  RandomForestRegressor  ...          7  1096.331131
# 480                    30       BaggingRegressor  ...          7  1096.332992
# 481                    13  RandomForestRegressor  ...          7  1096.336685
# 482                    27  RandomForestRegressor  ...          7  1096.352531
# 483                     9       BaggingRegressor  ...          7  1096.370116
# 484                    25  RandomForestRegressor  ...          7  1096.376191
# 485                    12  RandomForestRegressor  ...          7  1096.384859
# 486                    35       BaggingRegressor  ...          7  1096.385948
# 487                    31  RandomForestRegressor  ...          7  1096.393960
# 488                    29  RandomForestRegressor  ...          7  1096.397290
# 489                    36  RandomForestRegressor  ...          7  1096.407191
# 490                    12       BaggingRegressor  ...          7  1096.409875
# 491                    27       BaggingRegressor  ...          7  1096.415777
# 492                    34       BaggingRegressor  ...          7  1096.420759
# 493                    14  RandomForestRegressor  ...          7  1096.429377
# 494                    37       BaggingRegressor  ...          7  1096.441181
# 495                    14       BaggingRegressor  ...          7  1096.459313
# 496                    37       BaggingRegressor  ...          7  1096.460247
# 497                    30  RandomForestRegressor  ...          7  1096.465639
# 498                    31  RandomForestRegressor  ...          7  1096.468728
# 499                    14  RandomForestRegressor  ...          7  1096.486001
#
# [500 rows x 12 columns]

# %% [markdown]
# # Preparing the test set for evaluation

# %%
# Loading the test file.
filename = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Week_6/test_AbJTz2l.csv'

test_df = pd.read_csv(filename)

submission_columns_df = test_df[['Item_Identifier', 'Outlet_Identifier']]

# %% [markdown]
# ## Perform the feature engineering and imputation methods on the test set
# ## so it can be evaluated by the fitted machine learning model.

# %%
# Average visibility for each unique value of 'Item_Identifier', calculated during previous training data preparation.
average_visibility
# Out:
# Item_Identifier
# DRA12    0.031956
# DRA24    0.048062
# DRA59    0.134718
# DRB01    0.082126
# DRB13    0.008002
#            ...
# NCZ30    0.024956
# NCZ41    0.051623
# NCZ42    0.009044
# NCZ53    0.027775
# NCZ54    0.080426
# Name: Item_Visibility, Length: 1559, dtype: float64

# %%
# Create a filter to find all the rows where the visibility value is zero.
missing_visibility_filter = (test_df['Item_Visibility'] == 0)

# Change all values of visibility=0 to the average visibility value for that item type. 
test_df.loc[missing_visibility_filter, 'Item_Visibility'] = test_df.loc[missing_visibility_filter, 'Item_Identifier'].apply(lambda x: average_visibility[x])

# %%
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Binning Test Data Item_Id
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Create a new column "Item_Type_Binned" that contains the first two characters in the Item_Identifier string.
test_df['Item_Id_Binned'] = test_df['Item_Identifier'].apply(lambda x : x[0:2])


# Expand the two letter code in the "Item_Type_Binned" column (created above) into a more obvious category name.
test_df['Item_Id_Binned'] = test_df['Item_Id_Binned'].map({'FD' : 'Food', 'NC' : 'Non-Consumable', 'DR' : 'Drinks'})

# %%
# Create a new column 'Years of operation' that equals the number of years prior to 2013 that this store was established.
test_df['Years_of_operation'] = 2013 - test_df['Outlet_Establishment_Year']

# %%
# Make category names in the Item_Fat_Content feature consistent.
test_df['Item_Fat_Content'] = test_df['Item_Fat_Content'].replace({'LF' : 'Low Fat', 'reg' : 'Regular', 'low fat' : 'Low Fat'})

# Some "Non-Consumable" item types have a fat content listed. For all "Non-Consumable" items, change the fat content value to 
# a new category called "Not_Edible".
test_df.loc[sales_df['Item_Id_Binned'] == 'Non-Consumable', 'Item_Fat_Content'] = 'Not_Edible'

# Ensure the only values in the 'Item_Fat_Content' column are now "Low Fat", "Regular" and "Not_Edible"
# test_df['Item_Fat_Content'].value_counts()

# %%
# -------------------------------------------------------------------------------------------------------------------------
# Imputing the missing weight values using the average item weight for that item type. 
# -------------------------------------------------------------------------------------------------------------------------

# Create a filter to easily grab all the rows where the Item_Weight value is missing.
missing_weight_filter = (test_df['Item_Weight'].isna())

# Set each missing Item_Weight equal to the average item weight for that Item_Identifier (as calculated using the training data set).
# For example, for item 'DRA24' the weight value with be mapped to average_weight_per_item['DRA24'], which is 19.35 per the averages we calculated two lines above.
test_df.loc[missing_weight_filter, 'Item_Weight'] = test_df.loc[missing_weight_filter, 'Item_Identifier'].apply(lambda Item_ID : average_weight_per_item[Item_ID] )

# %%
# -------------------------------------------------------------------------------------------------------------------------
# Imputing the missing Outlet_Size values with the mode (most frequent) outlet size value for that outlet type.
# -------------------------------------------------------------------------------------------------------------------------

# Create a filter for easily accessing all the rows where the Outlet_Size value is missing.
missing_outlet_size = test_df['Outlet_Size'].isna()

# impute the missing values in the Outlet_Size column with the most frequent Outlet_Size for that Outlet_Type
test_df.loc[missing_outlet_size, 'Outlet_Size'] = test_df.loc[missing_outlet_size, 'Outlet_Type'].apply(lambda store_type : most_frequent_size_per_type[store_type])

# %%
test_df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  1
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Id_Binned               0
# Years_of_operation           0
# dtype: int64

# %%
# ---------------------------------------------------------------------------------------------------------------------------------------------------------
# There is still a single missing weight value. Just as we saw when processing the training set, this occurs when there is a missing weight value
# and there is no other items with that item_ID to average the weights of for imputation. In this case, we will impute the weight with the average
# weight for that item_type (a broader but still relevant category), as we did before.
# ---------------------------------------------------------------------------------------------------------------------------------------------------------

# Filter to easily select the four rows that still have missing Item_Weight values.
missing_weights = test_df['Item_Weight'].isna()

# Imputing the four remaining missing Item_Weight values with the average weight value for that item type. 
test_df.loc[missing_weights, 'Item_Weight'] = test_df.loc[missing_weights, 'Item_Type'].apply(lambda item_type : average_weights_per_type[item_type])

# %%
test_df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Id_Binned               0
# Years_of_operation           0
# dtype: int64

# %%
filepath = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/Sales_Test_Data_Cleaned_TrainImpute.csv'

test_df.to_csv(path_or_buf=filepath, index=False)

# Dropping the columns that were not used when training the machine learning model.
test_df.drop(columns=['Item_Identifier', 'Outlet_Establishment_Year'], inplace=True)

# %%
# Make sales predictions using the test data.
test_predictions = gs_results.predict(test_df)

# %%
# Convert the predictions to a dataframe.
predictions_df = pd.DataFrame(test_predictions)
predictions_df.rename(columns={0: 'Item_Outlet_Sales'}, inplace=True)

# %%
# Prepare the prediction for output.
full_submission_df = pd.concat([submission_columns_df, predictions_df], axis=1)

# %%
# Output the predictions to a csv file. 
filepath = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/Anderson_Sales_Prediction_Submission.csv'

full_submission_df.to_csv(path_or_buf=filepath, index=False)

# %% [markdown]
# # Submission 2 - imputing using all the available information

# %%
# Loading the test file.
filename = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Week_6/test_AbJTz2l.csv'

test_df = pd.read_csv(filename)

submission_columns_df = test_df[['Item_Identifier', 'Outlet_Identifier']]

# %%
# Load the training file (version that has not been cleaned, and missings have not been imputed). 
filename = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/sales_predictions.csv'

sales_df = pd.read_csv(filename)

# %%
# Combine the test and training file. This will allow us to easily use the data from both when imputing values in the test set.
combined_df = pd.concat([sales_df, test_df])

# %%
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Consider any products with item_visibility = 0 as having missing information. (Not realistic that the visibility of any item in a store is actually zero).
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Calculate the average visibility for each unique value of 'Item_Identifier'
average_visibility = combined_df.groupby(by='Item_Identifier')['Item_Visibility'].mean()

# Create a filter to find all the rows where the visibility value is zero.
missing_visibility_filter = (test_df['Item_Visibility'] == 0)

# Change all values of visibility=0 to the average visibility value for that item type. 
test_df.loc[missing_visibility_filter, 'Item_Visibility'] = test_df.loc[missing_visibility_filter, 'Item_Identifier'].apply(lambda x: average_visibility[x])

# %%
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Binning Test Data Item_Id
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# Create a new column "Item_Type_Binned" that contains the first two characters in the Item_Identifier string.
test_df['Item_Id_Binned'] = test_df['Item_Identifier'].apply(lambda x : x[0:2])


# Expand the two letter code in the "Item_Type_Binned" column (created above) into a more obvious category name.
test_df['Item_Id_Binned'] = test_df['Item_Id_Binned'].map({'FD' : 'Food', 'NC' : 'Non-Consumable', 'DR' : 'Drinks'})

# %%
# Create a new column 'Years of operation' that equals the number of years prior to 2013 that this store was established.
test_df['Years_of_operation'] = 2013 - test_df['Outlet_Establishment_Year']

# %%
# Make category names in the Item_Fat_Content feature consistent.
test_df['Item_Fat_Content'] = test_df['Item_Fat_Content'].replace({'LF' : 'Low Fat', 'reg' : 'Regular', 'low fat' : 'Low Fat'})

# Some "Non-Consumable" item types have a fat content listed. For all "Non-Consumable" items, change the fat content value to 
# a new category called "Not_Edible".
test_df.loc[test_df['Item_Id_Binned'] == 'Non-Consumable', 'Item_Fat_Content'] = 'Not_Edible'

# Ensure the only values in the 'Item_Fat_Content' column are now "Low Fat", "Regular" and "Not_Edible"
# test_df['Item_Fat_Content'].value_counts()

# %%
# -------------------------------------------------------------------------------------------------------------------------
# Imputing the missing weight values using the average item weight for that item type. 
# -------------------------------------------------------------------------------------------------------------------------

# Create groups of each unique item identifier. For each group, calculate the average item weight.
average_weight_per_item = combined_df.groupby(by="Item_Identifier")['Item_Weight'].mean()

# Create a filter to easily grab all the rows where the Item_Weight value is missing.
missing_weight_filter = (test_df['Item_Weight'].isna())

# Set each missing Item_Weight equal to the average item weight for that Item_Identifier.
# For example, for item 'DRA24' the weight value with be mapped to average_weight_per_item['DRA24'], which is 19.35 per the averages we calculated two lines above.
test_df.loc[missing_weight_filter, 'Item_Weight'] = test_df.loc[missing_weight_filter, 'Item_Identifier'].apply(lambda Item_ID : average_weight_per_item[Item_ID] )

# %%
# -------------------------------------------------------------------------------------------------------------------------
# Imputing the missing Outlet_Size values with the mode (most frequent) outlet size value for that outlet type.
# -------------------------------------------------------------------------------------------------------------------------

# Create groups for each unique value of Outlet_Type. For each outlet_type group, calculate the most frequent outlet_size. 
most_frequent_size_per_type = combined_df.groupby(by="Outlet_Type")['Outlet_Size'].agg(pd.Series.mode)

# Create a filter for easily accessing all the rows where the Outlet_Size value is missing.
missing_outlet_size = test_df['Outlet_Size'].isna()

# impute the missing values in the Outlet_Size column with the most frequent Outlet_Size for that Outlet_Type
test_df.loc[missing_outlet_size, 'Outlet_Size'] = test_df.loc[missing_outlet_size, 'Outlet_Type'].apply(lambda store_type : most_frequent_size_per_type[store_type])

# %%
test_df.isna().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Id_Binned               0
# Years_of_operation           0
# dtype: int64

# %%
filepath = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/Sales_Test_Data_Cleaned_ComboImpute.csv'

test_df.to_csv(path_or_buf=filepath, index=False)

# Dropping the columns that were not used when training the machine learning model.
test_df.drop(columns=['Item_Identifier', 'Outlet_Establishment_Year'], inplace=True)

# %%
test_predictions = gs_results.predict(test_df)

# %%
predictions_df = pd.DataFrame(test_predictions)
predictions_df.rename(columns={0: 'Item_Outlet_Sales'}, inplace=True)

# %%
full_submission_df = pd.concat([submission_columns_df, predictions_df], axis=1)

# %%
filepath = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/Anderson_Sales_Prediction_Submission2.csv'

full_submission_df.to_csv(path_or_buf=filepath, index=False)
