# %% [markdown]
# <a href="https://colab.research.google.com/github/BradenAnderson/sales-predictions/blob/main/03_Modeling_Part_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Braden Anderson
# ### Sales Predictions Project - Modeling Part 1
# ### Coding Dojo
# ### Data Science and Machine Learning Bootcamp

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import missingno
import pickle
import os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import BayesianRidge, LinearRegression, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor, RandomForestRegressor, BaggingRegressor 
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, StandardScaler, PowerTransformer
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.metrics import r2_score, mean_squared_error, SCORERS, mean_absolute_error
from sklearn.pipeline import Pipeline

# %matplotlib inline

# %%
filename = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/sales_predictions_clean.csv'

sales_df = pd.read_csv(filename, index_col=0)

# %%
a = sales_df.iloc[:,0].unique()
len(a)
sales_df.head()
# Out:
#   Item_Identifier  Item_Weight  ...        Outlet_Type  Item_Outlet_Sales
# 0           FDA15         9.30  ...  Supermarket Type1          3735.1380
# 1           DRC01         5.92  ...  Supermarket Type2           443.4228
# 2           FDN15        17.50  ...  Supermarket Type1          2097.2700
# 3           FDX07        19.20  ...      Grocery Store           732.3800
# 4           NCD19         8.93  ...  Supermarket Type1           994.7052
#
# [5 rows x 12 columns]

# %%
'''
numeric_feat = ['Item_Weight', 'Item_Visibility', 'Item_MRP']
ordinal_categorical_feat = ['Item_Fat_Content', 'Outlet_Establishment_Year', 'Outlet_Size']
nominal_categorical_feat = ["Item_Type", "Outlet_Identifier", "Outlet_Location_Type", "Outlet_Type"]

X = sales_df.loc[:, (sales_df.columns != 'Item_Outlet_Sales') & (sales_df.columns != 'Item_Identifier')]

y = sales_df["Item_Outlet_Sales"]

# ------------------------------------------------------------------------------------------------------------------------------------
# handle_unknown = 'ignore' is required for the OneHot encoder because the 'Item_Identifier' column has too many unique values.
# this means after one hot encoding, there will be some values that show up in the test set that were not seen in the training 
# set. By default this raises an error. Our only option (assuming we want to keep this column in the model, which in fact it may
# be better just to remove it), is to ignore the errors. 
#
# When errors are ignored, and an unknown parameter is encountered during the transform, the resulting one-hot encoded column
# for the unknown parameter will be all zeros, and in the inverse transform the unknown category will be denoted as "None". 
#
# ValueError: `handle_unknown` must be 'error' when the drop parameter is specified, as both would create categories that are all zero.
#---------------------------------------------------------------------------------------------------------------------------------------

preprocess = ColumnTransformer(transformers=[("std_scaler", StandardScaler(), numeric_feat),
                                             ("one_hot_encoder", OneHotEncoder(categories='auto', drop="first", sparse=False), nominal_categorical_feat), 
                                             ("ordinal_encoder", OrdinalEncoder(), ordinal_categorical_feat)],
                               remainder='passthrough')


total_columns = 36
column_list = list(range(total_columns + 1)) 
num_neighbors = list(range(1,40))

random_forest = RandomForestRegressor(random_state=42, oob_score=True)
bagged_trees = BaggingRegressor(random_state=42, oob_score=True)

num_trees = [1, 5, 10, 50, 100, 150, 200]
max_depth = [None, 7]

reg_strategy = TransformedTargetRegressor()
bcox_transformer = PowerTransformer(method='box-cox')
score_types = {'r2' :'r2', 'MSE' : 'neg_mean_squared_error'}

model_pipeline = Pipeline([("preprocessing", preprocess),
                           ('feature_selector', SelectKBest(f_regression)),
                           ('regress', reg_strategy)])


parameter_grid = [{'feature_selector__k' : column_list,                       # Vary the number of "Best" parameters to use when building the model.
                   'regress__regressor' : [LinearRegression(), Lasso()],      # Vary the model between Linear and Lasso regression. 
                   'regress__transformer' : [None, bcox_transformer]},        # Vary whether or not a box-cox transform is applied to the target vector.
                  {'feature_selector__k': column_list,                        # Vary the number of "Best" parameters to use when building the model. 
                   'regress__regressor' : [KNeighborsRegressor()],            # Use K Nearest Neighbors as the model.
                   'regress__regressor__n_neighbors' : num_neighbors,         # Vary the number of nearest neighbors the model uses from 1 to 39. 
                   'regress__regressor__weights' : ['uniform', 'distance'],   # Vary whether or the neighbors voting scheme is uniform of weighted by distance.
                   'regress__transformer' : [None, bcox_transformer]},        # Vary whether or not a box-cox transform is applied to the target. 
                  {'feature_selector__k': column_list,                        # Vary number of features the model uses.
                   'regress__regressor' : [random_forest],                    # Vary the model type to use a random forest
                   'regress__regressor__n_estimators' : num_trees,            # Vary the number of trees in the random forest
                   'regress__regressor__max_depth' : max_depth,               # Vary the max depth of each tree.
                   'regress__transformer' : [None, bcox_transformer]},        # Vary whether or not the target gets box-cox transformed.
                  {'feature_selector__k': column_list,                        # Vary the number of features used in the model.
                   'regress__regressor' : [bagged_trees],                     # Vary the model type to bagged trees.
                   'regress__regressor__n_estimators' : num_trees,            # Vary the number of trees used in the model.
                   'regress__regressor__base_estimator' : [DecisionTreeRegressor()],      # Each tree in the bagged trees model is a decision tree.
                   'regress__regressor__base_estimator__max_depth' : max_depth,           # Vary the max depth of each decision tree.
                   'regress__transformer' : [None, bcox_transformer]}]                    # Vary whether or not the target variable gets transformed. 


gs = GridSearchCV(estimator=model_pipeline, param_grid=parameter_grid, scoring=score_types, refit='MSE', cv=5, n_jobs=-1)

gs.fit(X, y)

PATH = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/'
gridsearch_result_filename = 'gridsearch_models_1.pkl'
full_path = PATH + gridsearch_result_filename
with open(full_path, 'wb') as file:
  pickle.dump(gs, file)

'''
# Out:
# '\nnumeric_feat = [\'Item_Weight\', \'Item_Visibility\', \'Item_MRP\']\nordinal_categorical_feat = [\'Item_Fat_Content\', \'Outlet_Establishment_Year\', \'Outlet_Size\']\nnominal_categorical_feat = ["Item_Type", "Outlet_Identifier", "Outlet_Location_Type", "Outlet_Type"]\n\nX = sales_df.loc[:, (sales_df.columns != \'Item_Outlet_Sales\') & (sales_df.columns != \'Item_Identifier\')]\n\ny = sales_df["Item_Outlet_Sales"]\n\n# ------------------------------------------------------------------------------------------------------------------------------------\n# handle_unknown = \'ignore\' is required for the OneHot encoder because the \'Item_Identifier\' column has too many unique values.\n# this means after one hot encoding, there will be some values that show up in the test set that were not seen in the training \n# set. By default this raises an error. Our only option (assuming we want to keep this column in the model, which in fact it may\n# be better just to remove it), is to ignore the errors. \n#\n# When errors are ignored, and an unknown parameter is encountered during the transform, the resulting one-hot encoded column\n# for the unknown parameter will be all zeros, and in the inverse transform the unknown category will be denoted as "None". \n#\n# ValueError: `handle_unknown` must be \'error\' when the drop parameter is specified, as both would create categories that are all zero.\n#---------------------------------------------------------------------------------------------------------------------------------------\n\npreprocess = ColumnTransformer(transformers=[("std_scaler", StandardScaler(), numeric_feat),\n                                             ("one_hot_encoder", OneHotEncoder(categories=\'auto\', drop="first", sparse=False), nominal_categorical_feat), \n                                             ("ordinal_encoder", OrdinalEncoder(), ordinal_categorical_feat)],\n                               remainder=\'passthrough\')\n\n\ntotal_columns = 36\ncolumn_list = list(range(total_columns + 1)) \nnum_neighbors = list(range(1,40))\n\nrandom_forest = RandomForestRegressor(random_state=42, oob_score=True)\nbagged_trees = BaggingRegressor(random_state=42, oob_score=True)\n\nnum_trees = [1, 5, 10, 50, 100, 150, 200]\nmax_depth = [None, 7]\n\nreg_strategy = TransformedTargetRegressor()\nbcox_transformer = PowerTransformer(method=\'box-cox\')\nscore_types = {\'r2\' :\'r2\', \'MSE\' : \'neg_mean_squared_error\'}\n\nmodel_pipeline = Pipeline([("preprocessing", preprocess),\n                           (\'feature_selector\', SelectKBest(f_regression)),\n                           (\'regress\', reg_strategy)])\n\n\nparameter_grid = [{\'feature_selector__k\' : column_list,                       # Vary the number of "Best" parameters to use when building the model.\n                   \'regress__regressor\' : [LinearRegression(), Lasso()],      # Vary the model between Linear and Lasso regression. \n                   \'regress__transformer\' : [None, bcox_transformer]},        # Vary whether or not a box-cox transform is applied to the target vector.\n                  {\'feature_selector__k\': column_list,                        # Vary the number of "Best" parameters to use when building the model. \n                   \'regress__regressor\' : [KNeighborsRegressor()],            # Use K Nearest Neighbors as the model.\n                   \'regress__regressor__n_neighbors\' : num_neighbors,         # Vary the number of nearest neighbors the model uses from 1 to 40. \n                   \'regress__regressor__weights\' : [\'uniform\', \'distance\'],   # Vary whether or the neighbors voting scheme is uniform of weighted by distance.\n                   \'regress__transformer\' : [None, bcox_transformer]},        # Vary whether or not a box-cox transform is applied to the target. \n                  {\'feature_selector__k\': column_list,                       \n                   \'regress__regressor\' : [random_forest],           \ ...

# %%
full_path = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Sales_Project/Current/gridsearch_models_1.pkl'

with open(full_path, 'rb') as file:
  gs_results = pickle.load(file)


X = sales_df.loc[:, (sales_df.columns != 'Item_Outlet_Sales') & (sales_df.columns != 'Item_Identifier')]
y = sales_df["Item_Outlet_Sales"]

Predict_For_MAE = gs_results.predict(X)
search_results = gs_results.cv_results_
top_estimator = gs_results.best_estimator_
top_score = gs_results.best_score_
top_parameters = gs_results.best_params_

# %%
mean_absolute_error(y, Predict_For_MAE)
# Out:
# 712.2291196699813

# %%
top_parameters
# Out:
# {'feature_selector__k': 35,
#  'regress__regressor': RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                        max_depth=7, max_features='auto', max_leaf_nodes=None,
#                        max_samples=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=True,
#                        random_state=42, verbose=0, warm_start=False),
#  'regress__regressor__max_depth': 7,
#  'regress__regressor__n_estimators': 100,
#  'regress__transformer': None}

# %%
#------------------------------------------------------------------------------------------------------------------------------------------------
# Perform Data Cleaning on the GridSearchCV output
#------------------------------------------------------------------------------------------------------------------------------------------------

gs_result_df = pd.DataFrame(search_results)

results_simplified_df= gs_result_df.loc[:,:].sort_values(by=['rank_test_MSE'], ignore_index=True)

results_simplified_df.rename(columns= {'param_feature_selector__k' : 'num_features_in_model',
                                       'param_regress__regressor' : 'model_type',
                                       'param_regress__transformer' : 'target_transformation',
                                       'param_regress__regressor__n_neighbors' : "Num_Nearest_Neighbors",
                                       'param_regress__regressor__weights' : "Neighbors_Score_Strategy",
                                       'param_regress__regressor__max_depth' : 'rand_forest_max_depth',
                                       'param_regress__regressor__n_estimators' : 'Number_of_Trees',
                                       'param_regress__regressor__base_estimator__max_depth' : 'bagged_tree_max_depth'}, inplace=True)

results_simplified_df = results_simplified_df.loc[:, ['num_features_in_model', 'model_type', 'target_transformation', 'Num_Nearest_Neighbors',
                                                      'Neighbors_Score_Strategy', 'rand_forest_max_depth', 'Number_of_Trees', 'bagged_tree_max_depth',
                                                      'mean_test_r2', 'rank_test_r2', 'mean_test_MSE', 'rank_test_MSE']]


# For easier viewing, combine 'rand_forest_max_depth' and 'bagged_tree_max_depth" into a single column called "tree_depth".
results_simplified_df['tree_depth'] = results_simplified_df['rand_forest_max_depth'].fillna(value=results_simplified_df['bagged_tree_max_depth'])
results_simplified_df['tree_depth'] = results_simplified_df['tree_depth'].fillna(value='No_Limit')
results_simplified_df.drop(columns=['rand_forest_max_depth', 'bagged_tree_max_depth'], inplace=True)

# Indicate if the model recieved a 'Box-cox' transformation of the target variable, or if not then list 'No_transformation'.
results_simplified_df['target_transformation'] = results_simplified_df['target_transformation'].fillna(value="No_Transformation")
results_simplified_df.loc[ (results_simplified_df['target_transformation'] != 'No_Transformation') , 'target_transformation'] = "Box-Cox"

# For easier viewing, trim model_type down so it only shows the name of the model used.
results_simplified_df['model_type'] = results_simplified_df['model_type'].astype(str)
results_simplified_df['model_type'] = results_simplified_df['model_type'].map(lambda model_string : model_string.split('(')[0])

results_simplified_df['Num_Nearest_Neighbors'] = results_simplified_df['Num_Nearest_Neighbors'].fillna(value='Not_Applicable')
results_simplified_df['Neighbors_Score_Strategy'] = results_simplified_df['Neighbors_Score_Strategy'].fillna(value='Not_Applicable')
results_simplified_df['Number_of_Trees'] = results_simplified_df['Number_of_Trees'].fillna(value='Not_Applicable')


# Negative MSE is not very interpretable. Take the absolute value and square root to get a more meaningful number. 
results_simplified_df['RMSE'] = results_simplified_df['mean_test_MSE'].abs().pow(1./2)

#https://stackoverflow.com/questions/51325601/how-to-stop-my-pandas-data-table-from-being-truncated-when-printed
pd.set_option('display.max_rows', 500)

results_simplified_df.head(500)
# Out:
#     num_features_in_model             model_type  ... tree_depth         RMSE
# 0                      35  RandomForestRegressor  ...          7  1086.602685
# 1                      35       BaggingRegressor  ...          7  1086.621121
# 2                      35  RandomForestRegressor  ...          7  1086.675639
# 3                      14       BaggingRegressor  ...          7  1086.710160
# 4                      35       BaggingRegressor  ...          7  1086.739648
# 5                      32  RandomForestRegressor  ...          7  1086.794289
# 6                      32  RandomForestRegressor  ...          7  1086.904421
# 7                      34       BaggingRegressor  ...          7  1086.915777
# 8                      34  RandomForestRegressor  ...          7  1086.916589
# 9                      34       BaggingRegressor  ...          7  1086.982791
# 10                     34  RandomForestRegressor  ...          7  1087.077825
# 11                     31  RandomForestRegressor  ...          7  1087.078829
# 12                      7  RandomForestRegressor  ...          7  1087.122527
# 13                     31       BaggingRegressor  ...          7  1087.135064
# 14                     33  RandomForestRegressor  ...          7  1087.141685
# 15                     31       BaggingRegressor  ...          7  1087.152182
# 16                     32       BaggingRegressor  ...          7  1087.169324
# 17                     35  RandomForestRegressor  ...          7  1087.187174
# 18                      7       BaggingRegressor  ...          7  1087.190898
# 19                     30  RandomForestRegressor  ...          7  1087.207528
# 20                     12  RandomForestRegressor  ...          7  1087.229043
# 21                     33       BaggingRegressor  ...          7  1087.252621
# 22                     31  RandomForestRegressor  ...          7  1087.252838
# 23                     12       BaggingRegressor  ...          7  1087.259190
# 24                     17       BaggingRegressor  ...          7  1087.264807
# 25                      7  RandomForestRegressor  ...          7  1087.266994
# 26                     14  RandomForestRegressor  ...          7  1087.278581
# 27                      7  RandomForestRegressor  ...          7  1087.284228
# 28                     32       BaggingRegressor  ...          7  1087.285902
# 29                      7       BaggingRegressor  ...          7  1087.312968
# 30                     10       BaggingRegressor  ...          7  1087.317008
# 31                     30  RandomForestRegressor  ...          7  1087.324662
# 32                      7       BaggingRegressor  ...          7  1087.328614
# 33                      8       BaggingRegressor  ...          7  1087.331815
# 34                     35       BaggingRegressor  ...          7  1087.351615
# 35                     10       BaggingRegressor  ...          7  1087.353347
# 36                      9  RandomForestRegressor  ...          7  1087.358323
# 37                     10  RandomForestRegressor  ...          7  1087.361447
# 38                     34       BaggingRegressor  ...          7  1087.362568
# 39                      9  RandomForestRegressor  ...          7  1087.365373
# 40                      9       BaggingRegressor  ...          7  1087.368442
# 41                     33       BaggingRegressor  ...          7  1087.369884
# 42                     15       BaggingRegressor  ...          7  1087.371097
# 43                     35  RandomForestRegressor  ...          7  1087.380011
# 44                     19  RandomForestRegressor  ...          7  1087.396503
# 45                     10  RandomForestRegressor  ...          7  1087.397213
# 46                      9       BaggingRegressor  ...          7  1087.414243
# 47                     17  RandomForestRegressor  ...          7  1087.416333
# 48                     11  RandomForestRegressor  ...          7  1087.420643
# 49                     18       BaggingRegressor  ...          7  1087.421991
# 50                     14       BaggingRegressor  ...          7  1087.422847
# 51                     35       BaggingRegressor  ...          7  1087.425520
# 52                     31       BaggingRegressor  ...          7  1087.435918
# 53                     32  RandomForestRegressor  ...          7  1087.438173
# 54                     34       BaggingRegressor  ...          7  1087.450978
# 55                     15  RandomForestRegressor  ...          7  1087.451340
# 56                      8       BaggingRegressor  ...          7  1087.461451
# 57                     12  RandomForestRegressor  ...          7  1087.468707
# 58                     34  RandomForestRegressor  ...          7  1087.470441
# 59                     18  RandomForestRegressor  ...          7  1087.479207
# 60                     10  RandomForestRegressor  ...          7  1087.480778
# 61                     31       BaggingRegressor  ...          7  1087.483999
# 62                     10       BaggingRegressor  ...          7  1087.494218
# 63                     13       BaggingRegressor  ...          7  1087.496557
# 64                     13  RandomForestRegressor  ...          7  1087.521773
# 65                     21       BaggingRegressor  ...          7  1087.526551
# 66                      9  RandomForestRegressor  ...          7  1087.527926
# 67                     31  RandomForestRegressor  ...          7  1087.538827
# 68                     34  RandomForestRegressor  ...          7  1087.539241
# 69                      9       BaggingRegressor  ...          7  1087.542153
# 70                     12  RandomForestRegressor  ...          7  1087.552474
# 71                      8  RandomForestRegressor  ...          7  1087.558262
# 72                     31  RandomForestRegressor  ...          7  1087.561249
# 73                     12       BaggingRegressor  ...          7  1087.566958
# 74                      8       BaggingRegressor  ...          7  1087.567354
# 75                     33  RandomForestRegressor  ...          7  1087.579000
# 76                      8  RandomForestRegressor  ...          7  1087.585210
# 77                     11       BaggingRegressor  ...          7  1087.586673
# 78                     32  RandomForestRegressor  ...          7  1087.587209
# 79                     16       BaggingRegressor  ...          7  1087.601384
# 80                     33  RandomForestRegressor  ...          7  1087.604404
# 81                     13  RandomForestRegressor  ...          7  1087.610416
# 82                     30       BaggingRegressor  ...          7  1087.619829
# 83                      8  RandomForestRegressor  ...          7  1087.640624
# 84                     12       BaggingRegressor  ...          7  1087.642709
# 85                     33  RandomForestRegressor  ...          7  1087.643737
# 86                     32       BaggingRegressor  ...          7  1087.645713
# 87                     11       BaggingRegressor  ...          7  1087.647746
# 88                     30  RandomForestRegressor  ...          7  1087.648083
# 89                     11  RandomForestRegressor  ...          7  1087.648341
# 90                     14       BaggingRegressor  ...          7  1087.658107
# 91                     29  RandomForestRegressor  ...          7  1087.667000
# 92                     30       BaggingRegressor  ...          7  1087.671750
# 93                     13  RandomForestRegressor  ...          7  1087.681705
# 94                     32       BaggingRegressor  ...          7  1087.697768
# 95                     28  RandomForestRegressor  ...          7  1087.701641
# 96                     30  RandomForestRegressor  ...          7  1087.706496
# 97                     13       BaggingRegressor  ...          7  1087.713270
# 98                     11       BaggingRegressor  ...          7  1087.720847
# 99                     11  RandomForestRegressor  ...          7  1087.739332
# 100                     7       BaggingRegressor  ...          7  1087.784258
# 101                    14  RandomForestRegressor  ...          7  1087.787462
# 102                    13       BaggingRegressor  ...          7  1087.810715
# 103                     7  RandomForestRegressor  ...          7  1087.820300
# 104                    19       BaggingRegressor  ...          7  1087.841367
# 105                    33       BaggingRegressor  ...          7  1087.843158
# 106                    30       BaggingRegressor  ...          7  1087.845599
# 107                    24  RandomForestRegressor  ...          7  1087.871605
# 108                    33       BaggingRegressor  ...          7  1087.874756
# 109                    29       BaggingRegressor  ...          7  1087.887014
# 110                    21  RandomForestRegressor  ...          7  1087.898659
# 111                     9       BaggingRegressor  ...          7  1087.916362
# 112                    28       BaggingRegressor  ...          7  1087.927402
# 113                    10  RandomForestRegressor  ...          7  1087.928969
# 114                    10       BaggingRegressor  ...          7  1087.929698
# 115                    12  RandomForestRegressor  ...          7  1087.943354
# 116                    14  RandomForestRegressor  ...          7  1087.953864
# 117                    15       BaggingRegressor  ...          7  1087.956399
# 118                     9  RandomForestRegressor  ...          7  1087.960145
# 119                    29  RandomForestRegressor  ...          7  1087.966874
# 120                    28       BaggingRegressor  ...          7  1087.968380
# 121                    17       BaggingRegressor  ...          7  1087.981718
# 122                    30       BaggingRegressor  ...          7  1087.983683
# 123                    16  RandomForestRegressor  ...          7  1087.989607
# 124                    24       BaggingRegressor  ...          7  1087.999214
# 125                    20       BaggingRegressor  ...          7  1088.005341
# 126                    14       BaggingRegressor  ...          7  1088.021959
# 127                     8       BaggingRegressor  ...          7  1088.029553
# 128                    15  RandomForestRegressor  ...          7  1088.038785
# 129                    27       BaggingRegressor  ...          7  1088.052270
# 130                    26       BaggingRegressor  ...          7  1088.052980
# 131                    25  RandomForestRegressor  ...          7  1088.059507
# 132                    22       BaggingRegressor  ...          7  1088.069663
# 133                    17  RandomForestRegressor  ...          7  1088.072635
# 134                    11  RandomForestRegressor  ...          7  1088.074618
# 135                    20  RandomForestRegressor  ...          7  1088.075078
# 136                     8  RandomForestRegressor  ...          7  1088.075306
# 137                    17  RandomForestRegressor  ...          7  1088.081816
# 138                    12       BaggingRegressor  ...          7  1088.084430
# 139                    28  RandomForestRegressor  ...          7  1088.095755
# 140                    11       BaggingRegressor  ...          7  1088.101550
# 141                    17       BaggingRegressor  ...          7  1088.104052
# 142                    13  RandomForestRegressor  ...          7  1088.130949
# 143                    15       BaggingRegressor  ...          7  1088.131217
# 144                    27       BaggingRegressor  ...          7  1088.143575
# 145                    25  RandomForestRegressor  ...          7  1088.166851
# 146                    29  RandomForestRegressor  ...          7  1088.173319
# 147                    29  RandomForestRegressor  ...          7  1088.179723
# 148                    18       BaggingRegressor  ...          7  1088.186903
# 149                    15  RandomForestRegressor  ...          7  1088.191530
# 150                    13       BaggingRegressor  ...          7  1088.201443
# 151                    28  RandomForestRegressor  ...          7  1088.207598
# 152                    16       BaggingRegressor  ...          7  1088.253210
# 153                    22  RandomForestRegressor  ...          7  1088.257463
# 154                    29       BaggingRegressor  ...          7  1088.260503
# 155                    29       BaggingRegressor  ...          7  1088.261918
# 156                    21       BaggingRegressor  ...          7  1088.262075
# 157                    14  RandomForestRegressor  ...          7  1088.270875
# 158                    29       BaggingRegressor  ...          7  1088.274966
# 159                    26       BaggingRegressor  ...          7  1088.284961
# 160                    27  RandomForestRegressor  ...          7  1088.314575
# 161                    25       BaggingRegressor  ...          7  1088.321725
# 162                    28  RandomForestRegressor  ...          7  1088.323536
# 163                    24  RandomForestRegressor  ...          7  1088.344481
# 164                    18       BaggingRegressor  ...          7  1088.347292
# 165                    27  RandomForestRegressor  ...          7  1088.356234
# 166                    28       BaggingRegressor  ...          7  1088.357949
# 167                    23       BaggingRegressor  ...          7  1088.359081
# 168                    24       BaggingRegressor  ...          7  1088.370025
# 169                    19  RandomForestRegressor  ...          7  1088.370040
# 170                    28       BaggingRegressor  ...          7  1088.370302
# 171                    18  RandomForestRegressor  ...          7  1088.381422
# 172                    16       BaggingRegressor  ...          7  1088.411724
# 173                    17  RandomForestRegressor  ...          7  1088.429516
# 174                    15       BaggingRegressor  ...          7  1088.436266
# 175                    17       BaggingRegressor  ...          7  1088.445083
# 176                    27       BaggingRegressor  ...          7  1088.448996
# 177                    18  RandomForestRegressor  ...          7  1088.473535
# 178                    27  RandomForestRegressor  ...          7  1088.478731
# 179                    21  RandomForestRegressor  ...          7  1088.495276
# 180                    26  RandomForestRegressor  ...          7  1088.514720
# 181                    25       BaggingRegressor  ...          7  1088.521288
# 182                    27       BaggingRegressor  ...          7  1088.527185
# 183                    26  RandomForestRegressor  ...          7  1088.533698
# 184                    25  RandomForestRegressor  ...          7  1088.538094
# 185                    15  RandomForestRegressor  ...          7  1088.538120
# 186                    26       BaggingRegressor  ...          7  1088.550232
# 187                    19       BaggingRegressor  ...          7  1088.567938
# 188                    16  RandomForestRegressor  ...          7  1088.571194
# 189                    19  RandomForestRegressor  ...          7  1088.573032
# 190                    21       BaggingRegressor  ...          7  1088.582110
# 191                    27  RandomForestRegressor  ...          7  1088.597941
# 192                    18       BaggingRegressor  ...          7  1088.601272
# 193                    26       BaggingRegressor  ...          7  1088.634194
# 194                    16  RandomForestRegressor  ...          7  1088.648060
# 195                    25  RandomForestRegressor  ...          7  1088.686883
# 196                    26  RandomForestRegressor  ...          7  1088.712984
# 197                    24  RandomForestRegressor  ...          7  1088.715715
# 198                    21  RandomForestRegressor  ...          7  1088.718408
# 199                    18  RandomForestRegressor  ...          7  1088.725668
# 200                    24       BaggingRegressor  ...          7  1088.744868
# 201                    25       BaggingRegressor  ...          7  1088.755560
# 202                    26  RandomForestRegressor  ...          7  1088.756724
# 203                    19       BaggingRegressor  ...          7  1088.773828
# 204                    20       BaggingRegressor  ...          7  1088.791687
# 205                    25       BaggingRegressor  ...          7  1088.815106
# 206                    19  RandomForestRegressor  ...          7  1088.815986
# 207                    22       BaggingRegressor  ...          7  1088.834816
# 208                    16       BaggingRegressor  ...          7  1088.854998
# 209                    22  RandomForestRegressor  ...          7  1088.858339
# 210                    23  RandomForestRegressor  ...          7  1088.861220
# 211                    20  RandomForestRegressor  ...          7  1088.892553
# 212                    19       BaggingRegressor  ...          7  1088.939238
# 213                    23       BaggingRegressor  ...          7  1088.946424
# 214                    24  RandomForestRegressor  ...          7  1088.969121
# 215                    24       BaggingRegressor  ...          7  1088.981944
# 216                    22       BaggingRegressor  ...          7  1088.985123
# 217                    16  RandomForestRegressor  ...          7  1088.988918
# 218                    21       BaggingRegressor  ...          7  1089.000618
# 219                    21  RandomForestRegressor  ...          7  1089.017938
# 220                    20       BaggingRegressor  ...          7  1089.061778
# 221                    22  RandomForestRegressor  ...          7  1089.076202
# 222                    23       BaggingRegressor  ...          7  1089.116332
# 223                    20  RandomForestRegressor  ...          7  1089.142541
# 224                    23  RandomForestRegressor  ...          7  1089.218532
# 225                    20       BaggingRegressor  ...          7  1089.271636
# 226                    23       BaggingRegressor  ...          7  1089.281662
# 227                    22       BaggingRegressor  ...          7  1089.294105
# 228                    20  RandomForestRegressor  ...          7  1089.340398
# 229                    22  RandomForestRegressor  ...          7  1089.393552
# 230                    23  RandomForestRegressor  ...          7  1089.394326
# 231                    23  RandomForestRegressor  ...          7  1089.467868
# 232                     9  RandomForestRegressor  ...          7  1090.631034
# 233                    17       BaggingRegressor  ...          7  1090.651007
# 234                    14  RandomForestRegressor  ...          7  1090.770223
# 235                    10       BaggingRegressor  ...          7  1090.860212
# 236                    15    KNeighborsRegressor  ...   No_Limit  1090.916204
# 237                    12       BaggingRegressor  ...          7  1090.931468
# 238                     7       BaggingRegressor  ...          7  1090.936126
# 239                    15    KNeighborsRegressor  ...   No_Limit  1090.979876
# 240                    15  RandomForestRegressor  ...          7  1091.025217
# 241                    14       BaggingRegressor  ...          7  1091.040986
# 242                    13  RandomForestRegressor  ...          7  1091.051246
# 243                    12  RandomForestRegressor  ...          7  1091.104194
# 244                    15    KNeighborsRegressor  ...   No_Limit  1091.159976
# 245                     9       BaggingRegressor  ...          7  1091.261377
# 246                    35  RandomForestRegressor  ...          7  1091.284609
# 247                    10  RandomForestRegressor  ...          7  1091.310927
# 248                     8  RandomForestRegressor  ...          7  1091.322674
# 249                     8       BaggingRegressor  ...          7  1091.328996
# 250                    34       BaggingRegressor  ...          7  1091.329118
# 251                    16    KNeighborsRegressor  ...   No_Limit  1091.331689
# 252                     7  RandomForestRegressor  ...          7  1091.357943
# 253                    11  RandomForestRegressor  ...          7  1091.368704
# 254                    19  RandomForestRegressor  ...          7  1091.442300
# 255                    13       BaggingRegressor  ...          7  1091.463606
# 256                    16       BaggingRegressor  ...          7  1091.565454
# 257                    35       BaggingRegressor  ...          7  1091.580605
# 258                    11       BaggingRegressor  ...          7  1091.608077
# 259                    16    KNeighborsRegressor  ...   No_Limit  1091.650892
# 260                    15       BaggingRegressor  ...          7  1091.650983
# 261                    15    KNeighborsRegressor  ...   No_Limit  1091.656493
# 262                    21  RandomForestRegressor  ...          7  1091.682329
# 263                     7    KNeighborsRegressor  ...   No_Limit  1091.696863
# 264                    16  RandomForestRegressor  ...          7  1091.709102
# 265                    17  RandomForestRegressor  ...          7  1091.721419
# 266                     7    KNeighborsRegressor  ...   No_Limit  1091.740191
# 267                     7    KNeighborsRegressor  ...   No_Limit  1091.748363
# 268                    16    KNeighborsRegressor  ...   No_Limit  1091.757517
# 269                    14    KNeighborsRegressor  ...   No_Limit  1091.857076
# 270                    32  RandomForestRegressor  ...          7  1091.876160
# 271                    34  RandomForestRegressor  ...          7  1091.880761
# 272                    22       BaggingRegressor  ...          7  1091.886467
# 273                     7    KNeighborsRegressor  ...   No_Limit  1091.894135
# 274                    15    KNeighborsRegressor  ...   No_Limit  1091.994162
# 275                    15    KNeighborsRegressor  ...   No_Limit  1092.004866
# 276                    21       BaggingRegressor  ...          7  1092.058769
# 277                    15    KNeighborsRegressor  ...   No_Limit  1092.065921
# 278                     7    KNeighborsRegressor  ...   No_Limit  1092.075559
# 279                     7    KNeighborsRegressor  ...   No_Limit  1092.081833
# 280                     7    KNeighborsRegressor  ...   No_Limit  1092.125580
# 281                    19       BaggingRegressor  ...          7  1092.131982
# 282                    28       BaggingRegressor  ...          7  1092.151596
# 283                    17    KNeighborsRegressor  ...   No_Limit  1092.189674
# 284                    30  RandomForestRegressor  ...          7  1092.190338
# 285                    31       BaggingRegressor  ...          7  1092.218327
# 286                     7    KNeighborsRegressor  ...   No_Limit  1092.219161
# 287                    18  RandomForestRegressor  ...          7  1092.219683
# 288                    14    KNeighborsRegressor  ...   No_Limit  1092.245857
# 289                    14    KNeighborsRegressor  ...   No_Limit  1092.247257
# 290                    15    KNeighborsRegressor  ...   No_Limit  1092.284167
# 291                     7    KNeighborsRegressor  ...   No_Limit  1092.300326
# 292                    31  RandomForestRegressor  ...          7  1092.314478
# 293                    17    KNeighborsRegressor  ...   No_Limit  1092.341871
# 294                     7    KNeighborsRegressor  ...   No_Limit  1092.477841
# 295                    33  RandomForestRegressor  ...          7  1092.504285
# 296                    33       BaggingRegressor  ...          7  1092.512877
# 297                    18       BaggingRegressor  ...          7  1092.528276
# 298                     7    KNeighborsRegressor  ...   No_Limit  1092.543800
# 299                    24  RandomForestRegressor  ...          7  1092.566905
# 300                    14    KNeighborsRegressor  ...   No_Limit  1092.569458
# 301                     7    KNeighborsRegressor  ...   No_Limit  1092.585795
# 302                    14    KNeighborsRegressor  ...   No_Limit  1092.621369
# 303                    15    KNeighborsRegressor  ...   No_Limit  1092.630123
# 304                    15    KNeighborsRegressor  ...   No_Limit  1092.661317
# 305                    15    KNeighborsRegressor  ...   No_Limit  1092.662846
# 306                    15    KNeighborsRegressor  ...   No_Limit  1092.666743
# 307                    30       BaggingRegressor  ...          7  1092.674492
# 308                    15    KNeighborsRegressor  ...   No_Limit  1092.685377
# 309                    22  RandomForestRegressor  ...          7  1092.703544
# 310                    24       BaggingRegressor  ...          7  1092.740815
# 311                     8    KNeighborsRegressor  ...   No_Limit  1092.749710
# 312                     7    KNeighborsRegressor  ...   No_Limit  1092.778699
# 313                    16    KNeighborsRegressor  ...   No_Limit  1092.784828
# 314                    20  RandomForestRegressor  ...          7  1092.855458
# 315                    17    KNeighborsRegressor  ...   No_Limit  1092.932008
# 316                    20       BaggingRegressor  ...          7  1092.938353
# 317                    14    KNeighborsRegressor  ...   No_Limit  1092.966383
# 318                    27  RandomForestRegressor  ...          7  1092.993634
# 319                    32       BaggingRegressor  ...          7  1092.994667
# 320                     8    KNeighborsRegressor  ...   No_Limit  1093.004676
# 321                    13    KNeighborsRegressor  ...   No_Limit  1093.047020
# 322                     9    KNeighborsRegressor  ...   No_Limit  1093.049174
# 323                    26       BaggingRegressor  ...          7  1093.068976
# 324                     7    KNeighborsRegressor  ...   No_Limit  1093.070495
# 325                     9    KNeighborsRegressor  ...   No_Limit  1093.072791
# 326                    12    KNeighborsRegressor  ...   No_Limit  1093.122645
# 327                    16    KNeighborsRegressor  ...   No_Limit  1093.129432
# 328                    13    KNeighborsRegressor  ...   No_Limit  1093.149805
# 329                     8    KNeighborsRegressor  ...   No_Limit  1093.169257
# 330                    11    KNeighborsRegressor  ...   No_Limit  1093.170872
# 331                    29  RandomForestRegressor  ...          7  1093.171686
# 332                    11    KNeighborsRegressor  ...   No_Limit  1093.176010
# 333                    10    KNeighborsRegressor  ...   No_Limit  1093.186550
# 334                    10    KNeighborsRegressor  ...   No_Limit  1093.187365
# 335                    12    KNeighborsRegressor  ...   No_Limit  1093.202711
# 336                    16    KNeighborsRegressor  ...   No_Limit  1093.231133
# 337                    16    KNeighborsRegressor  ...   No_Limit  1093.231276
# 338                     7    KNeighborsRegressor  ...   No_Limit  1093.245808
# 339                    27       BaggingRegressor  ...          7  1093.269698
# 340                    13    KNeighborsRegressor  ...   No_Limit  1093.283122
# 341                    14    KNeighborsRegressor  ...   No_Limit  1093.287976
# 342                     7    KNeighborsRegressor  ...   No_Limit  1093.310021
# 343                     9    KNeighborsRegressor  ...   No_Limit  1093.328447
# 344                    12    KNeighborsRegressor  ...   No_Limit  1093.334243
# 345                    14    KNeighborsRegressor  ...   No_Limit  1093.361711
# 346                    14    KNeighborsRegressor  ...   No_Limit  1093.385042
# 347                    14    KNeighborsRegressor  ...   No_Limit  1093.394752
# 348                    14    KNeighborsRegressor  ...   No_Limit  1093.397754
# 349                     9    KNeighborsRegressor  ...   No_Limit  1093.401222
# 350                     9    KNeighborsRegressor  ...   No_Limit  1093.401756
# 351                    23       BaggingRegressor  ...          7  1093.406090
# 352                    10    KNeighborsRegressor  ...   No_Limit  1093.415841
# 353                    29       BaggingRegressor  ...          7  1093.417265
# 354                    14    KNeighborsRegressor  ...   No_Limit  1093.419439
# 355                    11    KNeighborsRegressor  ...   No_Limit  1093.420740
# 356                    13    KNeighborsRegressor  ...   No_Limit  1093.429417
# 357                    14    KNeighborsRegressor  ...   No_Limit  1093.430193
# 358                    13    KNeighborsRegressor  ...   No_Limit  1093.502469
# 359                    15    KNeighborsRegressor  ...   No_Limit  1093.516151
# 360                    13    KNeighborsRegressor  ...   No_Limit  1093.534307
# 361                     8    KNeighborsRegressor  ...   No_Limit  1093.570678
# 362                    10    KNeighborsRegressor  ...   No_Limit  1093.578190
# 363                     9    KNeighborsRegressor  ...   No_Limit  1093.588054
# 364                    14    KNeighborsRegressor  ...   No_Limit  1093.590294
# 365                     8    KNeighborsRegressor  ...   No_Limit  1093.592442
# 366                    25  RandomForestRegressor  ...          7  1093.593456
# 367                    28  RandomForestRegressor  ...          7  1093.601758
# 368                    11    KNeighborsRegressor  ...   No_Limit  1093.626708
# 369                    10    KNeighborsRegressor  ...   No_Limit  1093.635977
# 370                    18    KNeighborsRegressor  ...   No_Limit  1093.646730
# 371                    12    KNeighborsRegressor  ...   No_Limit  1093.656668
# 372                     8    KNeighborsRegressor  ...   No_Limit  1093.666835
# 373                     9    KNeighborsRegressor  ...   No_Limit  1093.675026
# 374                    11    KNeighborsRegressor  ...   No_Limit  1093.708020
# 375                     8    KNeighborsRegressor  ...   No_Limit  1093.747181
# 376                     7    KNeighborsRegressor  ...   No_Limit  1093.748000
# 377                    12    KNeighborsRegressor  ...   No_Limit  1093.773346
# 378                     8    KNeighborsRegressor  ...   No_Limit  1093.773513
# 379                    10    KNeighborsRegressor  ...   No_Limit  1093.817157
# 380                     9    KNeighborsRegressor  ...   No_Limit  1093.832490
# 381                     8    KNeighborsRegressor  ...   No_Limit  1093.838974
# 382                    17    KNeighborsRegressor  ...   No_Limit  1093.841489
# 383                    17    KNeighborsRegressor  ...   No_Limit  1093.871639
# 384                    12    KNeighborsRegressor  ...   No_Limit  1093.879064
# 385                    11    KNeighborsRegressor  ...   No_Limit  1093.885292
# 386                    10    KNeighborsRegressor  ...   No_Limit  1093.911053
# 387                    11    KNeighborsRegressor  ...   No_Limit  1093.914961
# 388                    12    KNeighborsRegressor  ...   No_Limit  1093.923505
# 389                     9    KNeighborsRegressor  ...   No_Limit  1093.925015
# 390                    13    KNeighborsRegressor  ...   No_Limit  1093.944938
# 391                    26  RandomForestRegressor  ...          7  1093.958030
# 392                     9    KNeighborsRegressor  ...   No_Limit  1093.975433
# 393                     9    KNeighborsRegressor  ...   No_Limit  1094.000328
# 394                    12    KNeighborsRegressor  ...   No_Limit  1094.024024
# 395                     8    KNeighborsRegressor  ...   No_Limit  1094.088143
# 396                    11    KNeighborsRegressor  ...   No_Limit  1094.095242
# 397                    10    KNeighborsRegressor  ...   No_Limit  1094.102282
# 398                    10    KNeighborsRegressor  ...   No_Limit  1094.107583
# 399                    11    KNeighborsRegressor  ...   No_Limit  1094.110640
# 400                    13    KNeighborsRegressor  ...   No_Limit  1094.113927
# 401                    12    KNeighborsRegressor  ...   No_Limit  1094.130550
# 402                    16    KNeighborsRegressor  ...   No_Limit  1094.136417
# 403                    10    KNeighborsRegressor  ...   No_Limit  1094.140881
# 404                    12    KNeighborsRegressor  ...   No_Limit  1094.182100
# 405                    25       BaggingRegressor  ...          7  1094.203144
# 406                    11    KNeighborsRegressor  ...   No_Limit  1094.213796
# 407                    16    KNeighborsRegressor  ...   No_Limit  1094.214822
# 408                     9    KNeighborsRegressor  ...   No_Limit  1094.227466
# 409                    13    KNeighborsRegressor  ...   No_Limit  1094.229764
# 410                    10    KNeighborsRegressor  ...   No_Limit  1094.241186
# 411                     9    KNeighborsRegressor  ...   No_Limit  1094.242796
# 412                    11    KNeighborsRegressor  ...   No_Limit  1094.271280
# 413                    15    KNeighborsRegressor  ...   No_Limit  1094.278922
# 414                    14    KNeighborsRegressor  ...   No_Limit  1094.281618
# 415                    16    KNeighborsRegressor  ...   No_Limit  1094.308679
# 416                    12    KNeighborsRegressor  ...   No_Limit  1094.339365
# 417                    20    KNeighborsRegressor  ...   No_Limit  1094.340523
# 418                     8    KNeighborsRegressor  ...   No_Limit  1094.342916
# 419                    13    KNeighborsRegressor  ...   No_Limit  1094.376439
# 420                    16    KNeighborsRegressor  ...   No_Limit  1094.413895
# 421                     8    KNeighborsRegressor  ...   No_Limit  1094.417814
# 422                    16    KNeighborsRegressor  ...   No_Limit  1094.421168
# 423                    23  RandomForestRegressor  ...          7  1094.425575
# 424                    10    KNeighborsRegressor  ...   No_Limit  1094.427614
# 425                    14    KNeighborsRegressor  ...   No_Limit  1094.432236
# 426                    15    KNeighborsRegressor  ...   No_Limit  1094.434960
# 427                    17    KNeighborsRegressor  ...   No_Limit  1094.448779
# 428                    11    KNeighborsRegressor  ...   No_Limit  1094.469481
# 429                    12    KNeighborsRegressor  ...   No_Limit  1094.469669
# 430                    10    KNeighborsRegressor  ...   No_Limit  1094.475039
# 431                    11    KNeighborsRegressor  ...   No_Limit  1094.479616
# 432                    17    KNeighborsRegressor  ...   No_Limit  1094.508095
# 433                    12    KNeighborsRegressor  ...   No_Limit  1094.523092
# 434                    13    KNeighborsRegressor  ...   No_Limit  1094.561364
# 435                     7    KNeighborsRegressor  ...   No_Limit  1094.569245
# 436                    13    KNeighborsRegressor  ...   No_Limit  1094.582860
# 437                    18    KNeighborsRegressor  ...   No_Limit  1094.599090
# 438                    16    KNeighborsRegressor  ...   No_Limit  1094.599198
# 439                    13    KNeighborsRegressor  ...   No_Limit  1094.601797
# 440                    19    KNeighborsRegressor  ...   No_Limit  1094.609020
# 441                     9    KNeighborsRegressor  ...   No_Limit  1094.624937
# 442                    14    KNeighborsRegressor  ...   No_Limit  1094.649025
# 443                     7    KNeighborsRegressor  ...   No_Limit  1094.660936
# 444                    16    KNeighborsRegressor  ...   No_Limit  1094.679957
# 445                    21    KNeighborsRegressor  ...   No_Limit  1094.695507
# 446                     8    KNeighborsRegressor  ...   No_Limit  1094.704579
# 447                    16    KNeighborsRegressor  ...   No_Limit  1094.787558
# 448                     8    KNeighborsRegressor  ...   No_Limit  1094.793151
# 449                    10    KNeighborsRegressor  ...   No_Limit  1094.830023
# 450                    11    KNeighborsRegressor  ...   No_Limit  1094.870403
# 451                    12    KNeighborsRegressor  ...   No_Limit  1094.911960
# 452                     8    KNeighborsRegressor  ...   No_Limit  1094.958402
# 453                    18    KNeighborsRegressor  ...   No_Limit  1094.992990
# 454                    12    KNeighborsRegressor  ...   No_Limit  1095.050864
# 455                     9    KNeighborsRegressor  ...   No_Limit  1095.068172
# 456                    13    KNeighborsRegressor  ...   No_Limit  1095.082450
# 457                     8    KNeighborsRegressor  ...   No_Limit  1095.091632
# 458                    16    KNeighborsRegressor  ...   No_Limit  1095.127091
# 459                     7    KNeighborsRegressor  ...   No_Limit  1095.131841
# 460                    10    KNeighborsRegressor  ...   No_Limit  1095.133643
# 461                    11    KNeighborsRegressor  ...   No_Limit  1095.137366
# 462                    10       BaggingRegressor  ...          7  1095.240241
# 463                    20    KNeighborsRegressor  ...   No_Limit  1095.240713
# 464                    35  RandomForestRegressor  ...          7  1095.289517
# 465                    15    KNeighborsRegressor  ...   No_Limit  1095.331580
# 466                     9    KNeighborsRegressor  ...   No_Limit  1095.383492
# 467                    20    KNeighborsRegressor  ...   No_Limit  1095.420517
# 468                    12    KNeighborsRegressor  ...   No_Limit  1095.426925
# 469                     8    KNeighborsRegressor  ...   No_Limit  1095.445951
# 470                    21    KNeighborsRegressor  ...   No_Limit  1095.450672
# 471                    12       BaggingRegressor  ...          7  1095.456081
# 472                    10    KNeighborsRegressor  ...   No_Limit  1095.496752
# 473                    11    KNeighborsRegressor  ...   No_Limit  1095.500977
# 474                    30  RandomForestRegressor  ...          7  1095.501329
# 475                     7       BaggingRegressor  ...          7  1095.534770
# 476                    14    KNeighborsRegressor  ...   No_Limit  1095.548348
# 477                    13  RandomForestRegressor  ...          7  1095.549719
# 478                    11  RandomForestRegressor  ...          7  1095.552618
# 479                    12    KNeighborsRegressor  ...   No_Limit  1095.606519
# 480                     9  RandomForestRegressor  ...          7  1095.608235
# 481                     9    KNeighborsRegressor  ...   No_Limit  1095.612381
# 482                    10    KNeighborsRegressor  ...   No_Limit  1095.658956
# 483                    11    KNeighborsRegressor  ...   No_Limit  1095.659130
# 484                    16    KNeighborsRegressor  ...   No_Limit  1095.669213
# 485                    20    KNeighborsRegressor  ...   No_Limit  1095.679538
# 486                    20    KNeighborsRegressor  ...   No_Limit  1095.705215
# 487                    21  RandomForestRegressor  ...          7  1095.706522
# 488                    18    KNeighborsRegressor  ...   No_Limit  1095.712352
# 489                    17       BaggingRegressor  ...          7  1095.736861
# 490                    13    KNeighborsRegressor  ...   No_Limit  1095.738587
# 491                     9       BaggingRegressor  ...          7  1095.790815
# 492                    20    KNeighborsRegressor  ...   No_Limit  1095.791919
# 493                    34       BaggingRegressor  ...          7  1095.807743
# 494                    14  RandomForestRegressor  ...          7  1095.814410
# 495                    28       BaggingRegressor  ...          7  1095.827216
# 496                    13       BaggingRegressor  ...          7  1095.835094
# 497                    13    KNeighborsRegressor  ...   No_Limit  1095.840091
# 498                    14  RandomForestRegressor  ...          7  1095.862891
# 499                    19    KNeighborsRegressor  ...   No_Limit  1095.879964
#
# [500 rows x 12 columns]

# %%
filename = '/content/drive/MyDrive/Programming/Colab Notebooks/Coding_Dojo/Week_6/test_AbJTz2l.csv'

test_df = pd.read_csv(filename)

# %%
X = test_df.loc[:, (test_df.columns != 'Item_Outlet_Sales') & (test_df.columns != 'Item_Identifier')]
